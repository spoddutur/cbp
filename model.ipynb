# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
def read_glove_vecs(glove_file):
    with open(glove_file, 'r',encoding='UTF-8') as f:
        words = set()
        word_to_vec_map = {}
        for line in f:
            line = line.strip().split()
            curr_word = line[0]
            words.add(curr_word)
            word_to_vec_map[curr_word] = np.array(line[1:], dtype=np.float64)
        
        i = 1
        words_to_index = {}
        index_to_words = {}
        for w in sorted(words):
            words_to_index[w] = i
            index_to_words[i] = w
            i = i + 1
    return words_to_index, index_to_words, word_to_vec_map
  
words_to_index, index_to_words, word_to_vec_map = read_glove_vecs('/Users/surthi/Documents/cs230project/glove.6B.50d.txt')
print("Loaded ", len(word_to_vec_map), " model")
# Out:
# Loaded  400000  model

# %%
import itertools
def sentences_to_indices(X, word_to_index, max_len):
    """
    Converts an array of sentences (strings) into an array of indices corresponding to words in the sentences.
    
    Arguments:
    X -- array of sentences (strings), of shape (m, 1)
    word_to_index -- a dictionary containing the each word mapped to its index
    max_len -- maximum number of words in a sentence. You can assume every sentence in X is no longer than this. 
    
    Returns:
    X_indices -- array of indices corresponding to words in the sentences from X, of shape (m, max_len)
    """
    
    m = X.shape[0]                                   # number of training examples
    
    # Initialize X_indices as a numpy matrix of zeros and the correct shape (≈ 1 line)
    X_indices = np.ones((m, max_len))*-1
    
    for i in range(m):                               # loop over training examples
        
        # Convert the ith training sentence in lower case and split is into words. You should get a list of words.
        sentence_words =X[i].lower().split()
        
        # Initialize j to 0
        j = 0
        
        # Loop over the words of sentence_words
        for w in sentence_words:
            # Set the (i,j)th entry of X_indices to the index of the correct word.
            X_indices[i, j] = word_to_index[w] if w in word_to_index else -1
            # Increment j to j + 1
            j = j+1

    return X_indices
  
def sentence_to_target_mask(target, sentence, dim=50):
  target_words = target.split()
  types = []
  words_in_sentence = sentence.lower().split()
  for word in words_in_sentence:
    types.append([1. if word.lower() in target_words else 0.] * dim)
  return types

def triplets_to_indices(tr):
#     tr = triplets[0]['wrong_triplets']
    newrow = [['ljl1', 'ljl2', 'ljl3']]

    # padding to zero
    numberToAppend = 500 - len(tr)
    for i in range(numberToAppend):
        tr = itertools.chain(tr, newrow)
    
    # triplets to indices
    tr1 = []
    for t in tr:
        tr1.append(t[0] +  " " + t[1] + " " + t[2])  
    return sentences_to_indices(np.asarray(tr1),words_to_index, max_len = 60)

# %%
import glob
import os
import json

def read_triplets(triplets_file):
    data = []
    
    with open(triplets_file) as f:
        json_data = json.load(f);
        data.extend( json_data)

    print (len(data))

    #now split the data into 2 (one for correct and one for wrong id)
    final_data = []
    for item in data:
        dict = {}
        dict["question"] = item["question"]
        dict["name"]       = item["name"]
        dict["correct_id"] = item["correct_id"]
        dict["correct_triplets"] = item["correct_triplets"]
        dict["result"] = 1
        final_data.append(dict)
        
        dict1 = {}
        dict1["question"] = item["question"]
        dict1["name"]     = item["name"]
        dict1["wrong_id"] = item["wrong_id"]
        dict1["wrong_triplets"] = item["wrong_triplets"]
        dict1["result"] = 0
        final_data.append(dict1)

    print(len(final_data))
    data.clear() # free memory for data
    return final_data

inputData = read_triplets('/Users/surthi/Documents/cs230project/data_wiki_handshake/input_w_wiki_1.ipwk')
# question, name, correct_id, wrong_id, correct_triplets, wrong_triplets
# Out:
# 10
# 20

# %%
inputData
# Out:
# [{'question': "Fitzroy North is a suburb in Melbourne, Victoria, Australia, 4 km north-east from Melbourne's central business district. Its Local Government Area are the Cities of Yarra and Moreland. At the ",
#   'name': 'victoria',
#   'correct_id': 'Q36687',
#   'correct_triplets': [['Borough of Koroit', 'country', 'Australia'],
#    ['Borough of Koroit', 'country', 'Borough of Koroit'],
#    ['Borough of Koroit', 'instance of', 'Borough of Koroit'],
#    ['Borough of Koroit',
#     'instance of',
#     'former local government area of Australia'],
#    ['Borough of Koroit',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['Borough of Port Fairy', 'country', 'Australia'],
#    ['Borough of Port Fairy', 'instance of', 'Borough of Port Fairy'],
#    ['Borough of Port Fairy',
#     'instance of',
#     'former local government area of Australia'],
#    ['Borough of Port Fairy', 'instance of', 'geographical object'],
#    ['Borough of Port Fairy',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['Borough of Port Fairy', 'locator map image', 'Borough of Port Fairy'],
#    ['Borough of Sebastopol', 'country', 'Australia'],
#    ['Borough of Sebastopol', 'instance of', 'Borough of Sebastopol'],
#    ['Borough of Sebastopol',
#     'instance of',
#     'former local government area of Australia'],
#    ['Borough of Sebastopol',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['Borough of Wonthaggi', 'coordinate location', 'Borough of Wonthaggi'],
#    ['Borough of Wonthaggi', 'country', 'Australia'],
#    ['Borough of Wonthaggi', 'country', 'Borough of Wonthaggi'],
#    ['Borough of Wonthaggi', 'instance of', 'Borough of Wonthaggi'],
#    ['Borough of Wonthaggi',
#     'instance of',
#     'former local government area of Australia'],
#    ['Borough of Wonthaggi',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Altona', 'country', 'Australia'],
#    ['City of Altona', 'instance of', 'City of Altona'],
#    ['City of Altona',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Altona',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Ararat', 'country', 'Australia'],
#    ['City of Ararat', 'dissolved, abolished or demolished', 'City of Ararat'],
#    ['City of Ararat', 'inception', 'City of Ararat'],
#    ['City of Ararat', 'instance of', 'City of Ararat'],
#    ['City of Ararat',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Ararat',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Ararat', 'replaced by', 'City of Ararat'],
#    ['City of Ararat', 'replaced by', 'Rural City of Ararat'],
#    ['City of Bairnsdale', 'country', 'Australia'],
#    ['City of Bairnsdale', 'instance of', 'City of Bairnsdale'],
#    ['City of Bairnsdale',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Bairnsdale',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Bairnsdale', 'locator map image', 'City of Bairnsdale'],
#    ['City of Ballaarat', 'country', 'Australia'],
#    ['City of Ballaarat',
#     'dissolved, abolished or demolished',
#     'City of Ballaarat'],
#    ['City of Ballaarat', 'followed by', 'City of Ballaarat'],
#    ['City of Ballaarat', 'followed by', 'City of Ballarat'],
#    ['City of Ballaarat', 'instance of', 'City of Ballaarat'],
#    ['City of Ballaarat',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Ballaarat',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Benalla', 'country', 'Australia'],
#    ['City of Benalla', 'instance of', 'City of Benalla'],
#    ['City of Benalla',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Benalla',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Bendigo', 'country', 'Australia'],
#    ['City of Bendigo', 'instance of', 'City of Bendigo'],
#    ['City of Bendigo',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Bendigo',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Berwick', 'country', 'Australia'],
#    ['City of Berwick', 'instance of', 'City of Berwick'],
#    ['City of Berwick',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Berwick',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Box Hill', 'country', 'Australia'],
#    ['City of Box Hill', 'instance of', 'City of Box Hill'],
#    ['City of Box Hill',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Box Hill',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Brighton', 'country', 'Australia'],
#    ['City of Brighton', 'instance of', 'City of Brighton'],
#    ['City of Brighton',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Brighton',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Broadmeadows', 'country', 'Australia'],
#    ['City of Broadmeadows', 'instance of', 'City of Broadmeadows'],
#    ['City of Broadmeadows',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Broadmeadows',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Broadmeadows', 'locator map image', 'City of Broadmeadows'],
#    ['City of Brunswick', 'country', 'Australia'],
#    ['City of Brunswick', 'image', 'City of Brunswick'],
#    ['City of Brunswick', 'instance of', 'City of Brunswick'],
#    ['City of Brunswick',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Brunswick',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Brunswick', 'locator map image', 'City of Brunswick'],
#    ['City of Camberwell', 'country', 'Australia'],
#    ['City of Camberwell', 'instance of', 'City of Camberwell'],
#    ['City of Camberwell',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Camberwell',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Castlemaine', 'country', 'Australia'],
#    ['City of Castlemaine',
#     'dissolved, abolished or demolished',
#     'City of Castlemaine'],
#    ['City of Castlemaine', 'inception', 'City of Castlemaine'],
#    ['City of Castlemaine', 'instance of', 'City of Castlemaine'],
#    ['City of Castlemaine',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Castlemaine',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Caulfield', 'country', 'Australia'],
#    ['City of Caulfield', 'instance of', 'City of Caulfield'],
#    ['City of Caulfield',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Caulfield',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Chelsea', 'country', 'Australia'],
#    ['City of Chelsea', 'instance of', 'City of Chelsea'],
#    ['City of Chelsea',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Chelsea',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Coburg', 'country', 'Australia'],
#    ['City of Coburg', 'instance of', 'City of Coburg'],
#    ['City of Coburg',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Coburg',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Collingwood', 'country', 'Australia'],
#    ['City of Collingwood', 'instance of', 'City of Collingwood'],
#    ['City of Collingwood',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Collingwood',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Collingwood', 'locator map image', 'City of Collingwood'],
#    ['City of Cranbourne', 'country', 'Australia'],
#    ['City of Cranbourne', 'instance of', 'City of Cranbourne'],
#    ['City of Cranbourne',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Cranbourne',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Croydon', 'country', 'Australia'],
#    ['City of Croydon', 'instance of', 'City of Croydon'],
#    ['City of Croydon',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Croydon',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Dandenong', 'country', 'Australia'],
#    ['City of Dandenong', 'instance of', 'City of Dandenong'],
#    ['City of Dandenong',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Dandenong',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['City of Echuca', 'country', 'Australia'],
#    ['City of Echuca', 'followed by', 'Shire of Campaspe'],
#    ['City of Echuca', 'instance of', 'City of Echuca'],
#    ['City of Echuca',
#     'instance of',
#     'former local government area of Australia'],
#    ['City of Echuca', 'instance of', 'geographical object'],
#    ['City of Echuca',
#     'located in the administrative territorial entity',
#     'Victoria'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'Borough of Koroit'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'Borough of Port Fairy'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'Borough of Sebastopol'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'Borough of Wonthaggi'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Altona'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Ararat'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Bairnsdale'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Ballaarat'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Benalla'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Bendigo'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Berwick'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Box Hill'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Brighton'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Broadmeadows'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Brunswick'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Camberwell'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Castlemaine'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Caulfield'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Chelsea'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Coburg'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Collingwood'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Cranbourne'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Croydon'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Dandenong'],
#    ['Victoria',
#     'contains administrative territorial entity',
#     'City of Echuca'],
#    ['Victoria', 'country', 'Australia'],
#    ['Victoria', 'flag', 'flag of Victoria'],
#    ['Victoria',
#     'located in the administrative territorial entity',
#     'Australia'],
#    ['Victoria', 'sister city', 'Aichi Prefecture'],
#    ['flag of Victoria', 'Commons category', 'flag of Victoria'],
#    ['flag of Victoria',
#     'Encyclopædia Britannica Online ID',
#     'flag of Victoria'],
#    ['flag of Victoria', 'Flags of the World ID', 'flag of Victoria'],
#    ['flag of Victoria', 'Freebase ID', 'flag of Victoria'],
#    ['flag of Victoria', 'Unicode character', 'flag of Victoria'],
#    ['flag of Victoria', 'applies to territorial jurisdiction', 'Victoria'],
#    ['flag of Victoria',
#     'applies to territorial jurisdiction',
#     'flag of Victoria'],
#    ['flag of Victoria', 'depicts', 'Crux'],
#    ['flag of Victoria', 'depicts', "St Edward's Crown"],
#    ['flag of Victoria', 'depicts', 'Union Jack'],
#    ['flag of Victoria', 'depicts', 'field'],
#    ['flag of Victoria', 'depicts', 'flag of Victoria'],
#    ['flag of Victoria', 'instance of', 'flag'],
#    ['flag of Victoria', 'instance of', 'flag of Victoria']],
#   'result': 1},
#  {'question': "Fitzroy North is a suburb in Melbourne, Victoria, Australia, 4 km north-east from Melbourne's central business district. Its Local Government Area are the Cities of Yarra and Moreland. At the ",
#   'name': 'victoria',
#   'wrong_id': 'Q7926536',
#   'wrong_triplets': [['Canada', 'BBC Things ID', 'Canada'],
#    ['Canada', 'BabelNet id', 'Canada'],
#    ['Canada', 'BnF ID', 'Canada'],
#    ['Canada', 'Commons gallery', 'Canada'],
#    ['Canada', 'DMOZ ID', 'Canada'],
#    ['Canada', 'Dewey Decimal Classification', 'Canada'],
#    ['Canada', 'Encyclopædia Britannica Online ID', 'Canada'],
#    ['Canada', 'FAST ID', 'Canada'],
#    ['Canada', 'FIPS 10-4 (countries and regions)', 'Canada'],
#    ['Canada', 'Foursquare venue ID', 'Canada'],
#    ['Canada', 'Freebase ID', 'Canada'],
#    ['Canada', 'GeoNames ID', 'Canada'],
#    ['Canada', 'Gini coefficient', 'Canada'],
#    ['Canada', 'Gran Enciclopèdia Catalana ID', 'Canada'],
#    ['Canada', 'Great Russian Encyclopedia Online ID', 'Canada'],
#    ['Canada', 'HDS ID', 'Canada'],
#    ['Canada', 'Human Development Index', 'Canada'],
#    ['Canada', 'IOC country code', 'Canada'],
#    ['Canada', 'IPA transcription', 'Canada'],
#    ['Canada', 'ISNI', 'Canada'],
#    ['Canada', 'ITU letter code', 'Canada'],
#    ['Canada', 'LAC ID', 'Canada'],
#    ['Canada', 'Library of Congress authority ID', 'Canada'],
#    ['Canada', 'M.49 code', 'Canada'],
#    ['Canada', 'Marine Regions Geographic ID', 'Canada'],
#    ['Canada', 'MeSH ID', 'Canada'],
#    ['Canada', 'MusicBrainz area ID', 'Canada'],
#    ['Canada', 'NALT ID', 'Canada'],
#    ['Canada', 'NKCR AUT ID', 'Canada'],
#    ['Canada', 'National Archives Identifier', 'Canada'],
#    ['Canada', 'National Library of Israel ID', 'Canada'],
#    ['Canada', 'OmegaWiki Defined Meaning', 'Canada'],
#    ['Canada', 'OpenStreetMap Relation identifier', 'Canada'],
#    ['Canada', 'PPP GDP per capita', 'Canada'],
#    ['Canada', 'Stack Exchange tag', 'Canada'],
#    ['Canada', 'TGN ID', 'Canada'],
#    ['Canada', 'Twitter username', 'Canada'],
#    ['Canada', 'Unicode character', 'Canada'],
#    ['Canada', 'VIAF ID', 'Canada'],
#    ['Canada', 'YSO ID', 'Canada'],
#    ['Canada', 'age of majority', 'Canada'],
#    ['Canada', 'anthem', 'O Canada'],
#    ['Canada', 'area', 'Canada'],
#    ['Canada', 'award received', 'Canada'],
#    ['Canada', 'award received', 'Nansen Refugee Award'],
#    ['Canada', 'basic form of government', 'Canada'],
#    ['Canada', 'basic form of government', 'constitutional monarchy'],
#    ['Canada', 'basic form of government', 'federation'],
#    ['Canada', 'basic form of government', 'parliamentary monarchy'],
#    ['Canada', 'capital', 'Ottawa'],
#    ['Canada', 'category for films shot at this location', 'Canada'],
#    ['Canada', 'category for people born here', 'Canada'],
#    ['Canada', 'category for people who died here', 'Canada'],
#    ['Canada', 'category of associated people', 'Canada'],
#    ['Canada', 'category of people buried here', 'Canada'],
#    ['Canada', 'central bank', 'Bank of Canada'],
#    ['Canada', 'central bank', 'Canada'],
#    ['Canada', 'coat of arms', 'Arms of Canada'],
#    ['Canada', 'coat of arms image', 'Canada'],
#    ['Canada', 'contains administrative territorial entity', 'Alberta'],
#    ['Canada',
#     'contains administrative territorial entity',
#     'British Columbia'],
#    ['Canada', 'contains administrative territorial entity', 'Manitoba'],
#    ['Canada', 'contains administrative territorial entity', 'New Brunswick'],
#    ['Canada',
#     'contains administrative territorial entity',
#     'Newfoundland and Labrador'],
#    ['Canada',
#     'contains administrative territorial entity',
#     'Northwest Territories'],
#    ['Canada', 'contains administrative territorial entity', 'Nova Scotia'],
#    ['Canada', 'contains administrative territorial entity', 'Nunavut'],
#    ['Canada', 'contains administrative territorial entity', 'Ontario'],
#    ['Canada',
#     'contains administrative territorial entity',
#     'Prince Edward Island'],
#    ['Canada', 'contains administrative territorial entity', 'Quebec'],
#    ['Canada', 'contains administrative territorial entity', 'Saskatchewan'],
#    ['Canada', 'contains administrative territorial entity', 'Yukon'],
#    ['Canada', 'continent', 'North America'],
#    ['Canada', 'coordinate of easternmost point', 'Canada'],
#    ['Canada', 'coordinate of northernmost point', 'Canada'],
#    ['Canada', 'coordinate of southernmost point', 'Canada'],
#    ['Canada', 'coordinate of westernmost point', 'Canada'],
#    ['Canada', 'country', 'Canada'],
#    ['Canada', 'currency', 'Canadian dollar'],
#    ['Canada', 'deepest point', 'Arctic Ocean'],
#    ['Canada', 'deepest point', 'Canada'],
#    ['Canada', 'demonym', 'Canada'],
#    ['Canada',
#     'described by source',
#     'Brockhaus and Efron Encyclopedic Dictionary'],
#    ['Canada', 'described by source', 'Canada'],
#    ['Canada',
#     'described by source',
#     'Jewish Encyclopedia of Brockhaus and Efron'],
#    ['Canada',
#     'described by source',
#     'Small Brockhaus and Efron Encyclopedic Dictionary'],
#    ['Canada', 'described by source', 'Sytin Military Encyclopedia'],
#    ['Canada', 'diplomatic relation', 'Afghanistan'],
#    ['Canada', 'diplomatic relation', 'Algeria'],
#    ['Canada', 'diplomatic relation', 'Argentina'],
#    ['Canada', 'diplomatic relation', 'Armenia'],
#    ['Canada', 'diplomatic relation', 'Australia'],
#    ['Canada', 'diplomatic relation', 'Austria'],
#    ['Canada', 'diplomatic relation', 'Azerbaijan'],
#    ['Canada', 'diplomatic relation', 'Bangladesh'],
#    ['Canada', 'diplomatic relation', 'Barbados'],
#    ['Canada', 'diplomatic relation', 'Belgium'],
#    ['Canada', 'diplomatic relation', 'Brazil'],
#    ['Canada', 'diplomatic relation', 'Brunei'],
#    ['Canada', 'diplomatic relation', 'Bulgaria'],
#    ['Canada', 'diplomatic relation', 'Burkina Faso'],
#    ['Canada', 'diplomatic relation', 'Canada'],
#    ['Canada', 'diplomatic relation', 'Colombia'],
#    ['Canada', 'diplomatic relation', 'Cuba'],
#    ['Canada', 'diplomatic relation', 'Cyprus'],
#    ['Canada', 'diplomatic relation', 'Czech Republic'],
#    ['Canada', 'diplomatic relation', 'Democratic Republic of the Congo'],
#    ['Canada', 'diplomatic relation', 'Denmark'],
#    ['Canada', 'diplomatic relation', 'Egypt'],
#    ['Canada', 'diplomatic relation', 'Ethiopia'],
#    ['Canada', 'diplomatic relation', 'European Union'],
#    ['Canada', 'diplomatic relation', 'Finland'],
#    ['Canada', 'diplomatic relation', 'France'],
#    ['Canada', 'diplomatic relation', 'Georgia'],
#    ['Canada', 'diplomatic relation', 'Germany'],
#    ['Canada', 'diplomatic relation', 'Grecia'],
#    ['Canada', 'diplomatic relation', 'Greece'],
#    ['Canada', 'diplomatic relation', 'Grenada'],
#    ['Canada', 'diplomatic relation', 'Haiti'],
#    ['Canada', 'diplomatic relation', 'Holy See'],
#    ['Canada', 'diplomatic relation', 'Hong Kong'],
#    ['Canada', 'diplomatic relation', 'Iceland'],
#    ['Canada', 'diplomatic relation', 'India'],
#    ['Canada', 'diplomatic relation', 'Indonesia'],
#    ['Canada', 'diplomatic relation', 'Iran'],
#    ['Canada', 'diplomatic relation', 'Ireland'],
#    ['Canada', 'diplomatic relation', 'Israel'],
#    ['Canada', 'diplomatic relation', 'Jamaica'],
#    ['Canada', 'diplomatic relation', 'Japan'],
#    ['Canada', 'diplomatic relation', 'Kazakhstan'],
#    ['Canada', 'diplomatic relation', 'Kenya'],
#    ['Canada', 'diplomatic relation', 'Kingdom of the Netherlands'],
#    ['Canada', 'diplomatic relation', 'Latvia'],
#    ['Canada', 'diplomatic relation', 'Lebanon'],
#    ['Canada', 'diplomatic relation', 'Lithuania'],
#    ['Canada', 'diplomatic relation', 'Malaysia'],
#    ['Canada', 'diplomatic relation', 'Mali'],
#    ['Canada', 'diplomatic relation', 'Mexico'],
#    ['Canada', 'diplomatic relation', 'Mongolia'],
#    ['Canada', 'diplomatic relation', 'Morocco'],
#    ['Canada', 'diplomatic relation', 'Mozambique'],
#    ['Canada', 'diplomatic relation', 'Namibia'],
#    ['Canada', 'diplomatic relation', 'New Zealand'],
#    ['Canada', 'diplomatic relation', 'North Korea'],
#    ['Canada', 'diplomatic relation', 'Norway'],
#    ['Canada', 'diplomatic relation', 'Pakistan'],
#    ['Canada', 'diplomatic relation', 'Panama'],
#    ['Canada', 'diplomatic relation', "People's Republic of China"],
#    ['Canada', 'diplomatic relation', 'Philippines'],
#    ['Canada', 'diplomatic relation', 'Poland'],
#    ['Canada', 'diplomatic relation', 'Portugal'],
#    ['Canada', 'diplomatic relation', 'Qatar'],
#    ['Canada', 'diplomatic relation', 'Romania'],
#    ['Canada', 'diplomatic relation', 'Russia'],
#    ['Canada', 'diplomatic relation', 'Saudi Arabia'],
#    ['Canada', 'diplomatic relation', 'Singapore'],
#    ['Canada', 'diplomatic relation', 'Slovenia'],
#    ['Canada', 'diplomatic relation', 'South Africa'],
#    ['Canada', 'diplomatic relation', 'South Korea'],
#    ['Canada', 'diplomatic relation', 'Soviet Union'],
#    ['Canada', 'diplomatic relation', 'Spain'],
#    ['Canada', 'diplomatic relation', 'Sweden'],
#    ['Canada', 'diplomatic relation', 'Switzerland'],
#    ['Canada', 'diplomatic relation', 'Taiwan'],
#    ['Canada', 'diplomatic relation', 'Turkey'],
#    ['Canada', 'diplomatic relation', 'Ukraine'],
#    ['Canada', 'diplomatic relation', 'United Arab Emirates'],
#    ['Canada', 'diplomatic relation', 'United Kingdom'],
#    ['Canada', 'diplomatic relation', 'United States of America'],
#    ['Canada', 'diplomatic relation', 'Uruguay'],
#    ['Canada', 'diplomatic relation', 'Venezuela'],
#    ['Canada', 'diplomatic relation', 'Zambia'],
#    ['Canada', 'driving side', 'Canada'],
#    ['Canada', 'driving side', 'right'],
#    ['Canada', 'electrical plug type', 'Canada'],
#    ['Canada', 'electrical plug type', 'Type A'],
#    ['Canada', 'electrical plug type', 'Type B'],
#    ['Canada', 'emergency phone number', '9-1-1'],
#    ['Canada', 'emergency phone number', 'Canada'],
#    ['Canada', 'ethnic group', 'Canada'],
#    ['Canada', 'ethnic group', 'Canadians'],
#    ['Canada', 'ethnic group', 'Canadians of German ethnicity'],
#    ['Canada', 'ethnic group', 'Chinese Canadian'],
#    ['Canada', 'ethnic group', 'English Canadian'],
#    ['Canada', 'ethnic group', 'First Nations'],
#    ['Canada', 'ethnic group', 'French Canadian'],
#    ['Canada', 'ethnic group', 'Irish Canadian'],
#    ['Canada', 'ethnic group', 'Italian Canadians'],
#    ['Canada', 'ethnic group', 'Scottish Canadian'],
#    ['Canada', 'executive body', 'Canada'],
#    ['Canada', 'executive body', "Queen's Privy Council for Canada"],
#    ['Canada', 'flag', 'Canada'],
#    ['Canada', 'flag', 'flag of Canada'],
#    ['Canada', 'flag image', 'Canada'],
#    ['Canada', 'foundational text', 'Canada'],
#    ['Canada', 'foundational text', 'Constitution Act, 1867'],
#    ['Canada', 'geography of topic', 'Canada'],
#    ['Canada', 'geography of topic', 'geography of Canada'],
#    ['Canada', 'has quality', 'Canada'],
#    ['Canada', 'has quality', 'Free country'],
#    ['Canada', 'head of government', 'Canada'],
#    ['Canada', 'head of government', 'Justin Trudeau'],
#    ['Canada', 'head of state', 'Canada'],
#    ['Canada', 'head of state', 'Elizabeth II'],
#    ['Canada', 'highest judicial authority', 'Canada'],
#    ['Canada', 'highest judicial authority', 'Supreme Court of Canada'],
#    ['Canada', 'highest point', 'Canada'],
#    ['Canada', 'highest point', 'Mount Logan'],
#    ['Canada', 'history of topic', 'Canada'],
#    ['Canada', 'history of topic', 'history of Canada'],
#    ['Canada', 'inception', 'Canada'],
#    ['Canada', 'inflation rate', 'Canada'],
#    ['Canada', 'instance of', 'Canada'],
#    ['Canada', 'instance of', 'country'],
#    ['Canada', 'instance of', 'sovereign state'],
#    ['Canada', 'language used', 'Canada'],
#    ['Canada', 'language used', 'English'],
#    ['Canada', 'language used', 'French'],
#    ['Canada', 'legislative body', 'Parliament of Canada'],
#    ['Canada', 'licence plate code', 'Canada'],
#    ['Canada', 'life expectancy', 'Canada'],
#    ['Canada', 'located in time zone', 'Canada'],
#    ['Canada', 'located next to body of water', 'Arctic Ocean'],
#    ['Canada', 'located next to body of water', 'Atlantic Ocean'],
#    ['Canada', 'located next to body of water', 'Canada'],
#    ['Canada', 'located next to body of water', 'Great Lakes'],
#    ['Canada', 'located next to body of water', 'Pacific Ocean'],
#    ['Canada', 'locator map image', 'Canada'],
#    ['Canada', 'mains voltage', 'Canada'],
#    ['Canada', 'maritime identification digits', 'Canada'],
#    ['Canada', 'member of', 'ABCA Armies'],
#    ['Canada', 'member of', 'AUSCANNZUKUS'],
#    ['Canada', 'member of', 'African Development Bank'],
#    ['Canada', 'member of', 'Air and Space Interoperability Council'],
#    ['Canada', 'member of', 'Arctic Council'],
#    ['Canada', 'member of', 'Asia-Pacific Economic Cooperation'],
#    ['Canada', 'member of', 'Asian Development Bank'],
#    ['Canada',
#     'member of',
#     'Association of Southeast Asian Nations Regional Forum'],
#    ['Canada', 'member of', 'Australia Group'],
#    ['Canada', 'member of', 'Canada'],
#    ['Canada', 'member of', 'Caribbean Development Bank'],
#    ['Canada', 'member of', 'Combined Communications Electronics Board'],
#    ['Canada', 'member of', 'Commonwealth of Nations'],
#    ['Canada', 'member of', 'G20'],
#    ['Canada', 'member of', 'G8'],
#    ['Canada', 'member of', 'Group on Earth Observations'],
#    ['Canada',
#     'member of',
#     'International Bank for Reconstruction and Development'],
#    ['Canada',
#     'member of',
#     'International Centre for Settlement of Investment Disputes'],
#    ['Canada', 'member of', 'International Development Association'],
#    ['Canada', 'member of', 'International Energy Agency'],
#    ['Canada', 'member of', 'International Finance Corporation'],
#    ['Canada', 'member of', 'International Hydrographic Organization'],
#    ['Canada', 'member of', 'Interpol'],
#    ['Canada', 'member of', 'League of Nations'],
#    ['Canada', 'member of', 'Missile Technology Control Regime'],
#    ['Canada', 'member of', 'Movement Coordination Centre Europe'],
#    ['Canada', 'member of', 'Multilateral Investment Guarantee Agency'],
#    ['Canada', 'member of', 'North American Free Trade Agreement'],
#    ['Canada', 'member of', 'North Atlantic Treaty Organisation'],
#    ['Canada', 'member of', 'Nuclear Suppliers Group'],
#    ['Canada',
#     'member of',
#     'Organisation for the Prohibition of Chemical Weapons'],
#    ['Canada', 'member of', 'Organisation internationale de la Francophonie'],
#    ['Canada',
#     'member of',
#     'Organization for Economic Co-operation and Development'],
#    ['Canada',
#     'member of',
#     'Organization for Security and Co-operation in Europe'],
#    ['Canada', 'member of', 'Organization of American States'],
#    ['Canada', 'member of', 'The Technical Cooperation Program'],
#    ['Canada', 'member of', 'Treaty on Open Skies'],
#    ['Canada', 'member of', 'United Nations'],
#    ['Canada',
#     'member of',
#     'United Nations Educational, Scientific and Cultural Organization'],
#    ['Canada', 'member of', 'World Trade Organization'],
#    ['Canada', 'mobile country code', 'Canada'],
#    ['Canada', 'motto', 'A Mari Usque Ad Mare'],
#    ['Canada', 'motto', 'Canada'],
#    ['Canada', 'motto text', 'Canada'],
#    ['Canada', 'named after', 'Stadacona'],
#    ['Canada', 'native label', 'Canada'],
#    ['Canada', 'nominal GDP', 'Canada'],
#    ['Canada', 'nominal GDP per capita', 'Canada'],
#    ['Canada', 'office held by head of government', 'Canada'],
#    ['Canada', 'office held by head of government', 'Prime Minister of Canada'],
#    ['Canada', 'office held by head of state', 'Canada'],
#    ['Canada', 'office held by head of state', 'monarch of Canada'],
#    ['Canada', 'official language', 'English'],
#    ['Canada', 'official language', 'French'],
#    ['Canada', 'official name', 'Canada'],
#    ['Canada', 'official symbol', 'Canada'],
#    ['Canada', 'official symbol', 'North American beaver'],
#    ['Canada', 'official website', 'Canada'],
#    ['Canada', 'page banner', 'Canada'],
#    ['Canada', 'participant of', 'Canada'],
#    ['Canada', 'participant of', 'Pacific War'],
#    ['Canada', 'patron saint', 'Canada'],
#    ['Canada', 'patron saint', 'Jean de Brébeuf'],
#    ['Canada', 'patron saint', 'Joseph'],
#    ['Canada', 'patron saint', 'North American Martyrs'],
#    ['Canada', 'patron saint', 'Saint Anna'],
#    ['Canada', 'permanent duplicated item', 'Canada'],
#    ['Canada', 'population', 'Canada'],
#    ['Canada', 'pronunciation audio', 'Canada'],
#    ['Canada', 'public holiday', 'Canada'],
#    ['Canada', 'public holiday', 'Canada Day'],
#    ['Canada', 'public holiday', 'Christmas'],
#    ['Canada', 'public holiday', 'Good Friday'],
#    ['Canada', 'public holiday', 'Labour Day'],
#    ['Canada', 'public holiday', "New Year's Day"],
#    ['Canada', 'public holiday', 'Thanksgiving'],
#    ['Canada', 'real gross domestic product growth rate', 'Canada'],
#    ['Canada', 'replaces', 'Canada'],
#    ['Canada', 'replaces', 'Province of Canada'],
#    ['Canada', 'retirement age', 'Canada'],
#    ['Canada', 'seal description', 'Great Seal of Canada'],
#    ['Canada', 'seal image', 'Canada'],
#    ['Canada', 'separated from', 'Canada'],
#    ['Canada', 'separated from', 'United Kingdom'],
#    ['Canada', 'separated from', 'United Kingdom of Great Britain and Ireland'],
#    ['Canada', 'shares border with', 'Canada'],
#    ['Canada', 'shares border with', 'Greenland'],
#    ['Canada', 'shares border with', 'Saint Pierre and Miquelon'],
#    ['Canada', 'shares border with', 'United States of America'],
#    ['Canada', 'short name', 'Canada'],
#    ['Canada', 'top-level internet domain', '.ca'],
#    ['Canada', "topic's main Wikimedia portal", 'Canada'],
#    ['Canada', "topic's main category", 'Canada'],
#    ['Canada', 'total reserves', 'Canada'],
#    ['Canada', 'unemployment rate', 'Canada'],
#    ['Victoria', 'country', 'Canada']],
#   'result': 0},
#  {'question': " Fitzroy North and the neighbouring suburb of Northcote. Smith Street and Queen's Parade form the border with Clifton Hill. History. Fitzroy North Post Office opened on 2 February ",
#   'name': 'clifton hill',
#   'correct_id': 'Q5133240',
#   'correct_triplets': [['Australia', 'BNE ID', 'Australia'],
#    ['Australia', 'BnF ID', 'Australia'],
#    ['Australia', 'CiNii author ID', 'Australia'],
#    ['Australia', 'Commons gallery', 'Australia'],
#    ['Australia', 'DMOZ ID', 'Australia'],
#    ['Australia', 'Encyclopædia Britannica Online ID', 'Australia'],
#    ['Australia', 'FIPS 10-4 (countries and regions)', 'Australia'],
#    ['Australia', 'Freebase ID', 'Australia'],
#    ['Australia', 'GND ID', 'Australia'],
#    ['Australia', 'GeoNames ID', 'Australia'],
#    ['Australia', 'Gini coefficient', 'Australia'],
#    ['Australia', 'Gran Enciclopèdia Catalana ID', 'Australia'],
#    ['Australia', 'HDS ID', 'Australia'],
#    ['Australia', 'Human Development Index', 'Australia'],
#    ['Australia', 'IOC country code', 'Australia'],
#    ['Australia', 'IPA transcription', 'Australia'],
#    ['Australia', 'ISNI', 'Australia'],
#    ['Australia', 'Iconclass notation', 'Australia'],
#    ['Australia', 'Jewish Encyclopedia ID (Russian)', 'Australia'],
#    ['Australia', 'Library of Congress authority ID', 'Australia'],
#    ['Australia', 'M.49 code', 'Australia'],
#    ['Australia', 'MeSH ID', 'Australia'],
#    ['Australia', 'MusicBrainz area ID', 'Australia'],
#    ['Australia', 'NALT ID', 'Australia'],
#    ['Australia', 'NDL Auth ID', 'Australia'],
#    ['Australia', 'NKCR AUT ID', 'Australia'],
#    ['Australia', 'National Archives Identifier', 'Australia'],
#    ['Australia', 'National Library of Israel ID', 'Australia'],
#    ['Australia', 'OpenStreetMap Relation identifier', 'Australia'],
#    ['Australia', 'People Australia ID', 'Australia'],
#    ['Australia', 'SUDOC authorities', 'Australia'],
#    ['Australia', 'TGN ID', 'Australia'],
#    ['Australia', 'Unicode character', 'Australia'],
#    ['Australia', 'VIAF ID', 'Australia'],
#    ['Australia', 'anthem', 'Advance Australia Fair'],
#    ['Australia', 'anthem', 'Australia'],
#    ['Australia', 'area', 'Australia'],
#    ['Australia', 'basic form of government', 'Australia'],
#    ['Australia', 'basic form of government', 'constitutional monarchy'],
#    ['Australia', 'basic form of government', 'federation'],
#    ['Australia', 'basic form of government', 'parliamentary monarchy'],
#    ['Australia', 'capital', 'Australia'],
#    ['Australia', 'capital', 'Canberra'],
#    ['Australia', 'category for films shot at this location', 'Australia'],
#    ['Australia', 'category for people born here', 'Australia'],
#    ['Australia', 'category for people who died here', 'Australia'],
#    ['Australia', 'category of associated people', 'Australia'],
#    ['Australia', 'category of people buried here', 'Australia'],
#    ['Australia', 'central bank', 'Australia'],
#    ['Australia', 'central bank', 'Reserve Bank of Australia'],
#    ['Australia', 'central government debt as a percent of GDP', 'Australia'],
#    ['Australia', 'coat of arms', 'Australia'],
#    ['Australia', 'coat of arms', 'Coat of arms of Australia'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'Ashmore and Cartier Islands'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'Australian Antarctic Territory'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'Australian Capital Territory'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'Christmas Island'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'Cocos (Keeling) Islands'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'Coral Sea Islands'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'Heard Island and McDonald Islands'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'Jervis Bay Territory'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'New South Wales'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'Norfolk Island'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'Northern Territory'],
#    ['Australia', 'contains administrative territorial entity', 'Queensland'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'South Australia'],
#    ['Australia', 'contains administrative territorial entity', 'Tasmania'],
#    ['Australia', 'contains administrative territorial entity', 'Victoria'],
#    ['Australia',
#     'contains administrative territorial entity',
#     'Western Australia'],
#    ['Australia', 'continent', 'Australia'],
#    ['Australia', 'coordinate of easternmost point', 'Australia'],
#    ['Australia', 'coordinate of northernmost point', 'Australia'],
#    ['Australia', 'coordinate of southernmost point', 'Australia'],
#    ['Australia', 'coordinate of westernmost point', 'Australia'],
#    ['Australia', 'country', 'Australia'],
#    ['Australia', 'country calling code', 'Australia'],
#    ['Australia', 'currency', 'Australia'],
#    ['Australia', 'currency', 'Australian dollar'],
#    ['Australia', 'deepest point', 'Australia'],
#    ['Australia', 'deepest point', 'Lake Eyre'],
#    ['Australia', 'demonym', 'Australia'],
#    ['Australia', 'described by source', '1911 Encyclopædia Britannica'],
#    ['Australia', 'described by source', 'Australia'],
#    ['Australia',
#     'described by source',
#     'Brockhaus and Efron Encyclopedic Dictionary'],
#    ['Australia',
#     'described by source',
#     'Jewish Encyclopedia of Brockhaus and Efron'],
#    ['Australia', 'described by source', 'Orthodox Theological Encyclopedia'],
#    ['Australia',
#     'described by source',
#     'Small Brockhaus and Efron Encyclopedic Dictionary'],
#    ['Australia', 'described by source', 'Sytin Military Encyclopedia'],
#    ['Australia', 'different from', 'Australia'],
#    ['Australia', 'diplomatic relation', 'Afghanistan'],
#    ['Australia', 'diplomatic relation', 'Angola'],
#    ['Australia', 'diplomatic relation', 'Antigua and Barbuda'],
#    ['Australia', 'diplomatic relation', 'Argentina'],
#    ['Australia', 'diplomatic relation', 'Australia'],
#    ['Australia', 'diplomatic relation', 'Austria'],
#    ['Australia', 'diplomatic relation', 'Bangladesh'],
#    ['Australia', 'diplomatic relation', 'Barbados'],
#    ['Australia', 'diplomatic relation', 'Belgium'],
#    ['Australia', 'diplomatic relation', 'Bolivia'],
#    ['Australia', 'diplomatic relation', 'Bosnia and Herzegovina'],
#    ['Australia', 'diplomatic relation', 'Botswana'],
#    ['Australia', 'diplomatic relation', 'Brazil'],
#    ['Australia', 'diplomatic relation', 'Brunei'],
#    ['Australia', 'diplomatic relation', 'Bulgaria'],
#    ['Australia', 'diplomatic relation', 'Cambodia'],
#    ['Australia', 'diplomatic relation', 'Cameroon'],
#    ['Australia', 'diplomatic relation', 'Canada'],
#    ['Australia', 'diplomatic relation', 'Chile'],
#    ['Australia', 'diplomatic relation', 'Colombia'],
#    ['Australia', 'diplomatic relation', 'Costa Rica'],
#    ['Australia', 'diplomatic relation', 'Croatia'],
#    ['Australia', 'diplomatic relation', 'Cyprus'],
#    ['Australia', 'diplomatic relation', 'Czech Republic'],
#    ['Australia', 'diplomatic relation', 'Denmark'],
#    ['Australia', 'diplomatic relation', 'Djibouti'],
#    ['Australia', 'diplomatic relation', 'Dominican Republic'],
#    ['Australia', 'diplomatic relation', 'East Timor'],
#    ['Australia', 'diplomatic relation', 'Ecuador'],
#    ['Australia', 'diplomatic relation', 'Egypt'],
#    ['Australia', 'diplomatic relation', 'El Salvador'],
#    ['Australia', 'diplomatic relation', 'Estonia'],
#    ['Australia', 'diplomatic relation', 'Ethiopia'],
#    ['Australia', 'diplomatic relation', 'European Union'],
#    ['Australia', 'diplomatic relation', 'Federated States of Micronesia'],
#    ['Australia', 'diplomatic relation', 'Fiji'],
#    ['Australia', 'diplomatic relation', 'Finland'],
#    ['Australia', 'diplomatic relation', 'France'],
#    ['Australia', 'diplomatic relation', 'French Polynesia'],
#    ['Australia', 'diplomatic relation', 'Georgia'],
#    ['Australia', 'diplomatic relation', 'Germany'],
#    ['Australia', 'diplomatic relation', 'Ghana'],
#    ['Australia', 'diplomatic relation', 'Grecia'],
#    ['Australia', 'diplomatic relation', 'Greece'],
#    ['Australia', 'diplomatic relation', 'Grenada'],
#    ['Australia', 'diplomatic relation', 'Guatemala'],
#    ['Australia', 'diplomatic relation', 'Guyana'],
#    ['Australia', 'diplomatic relation', 'Holy See'],
#    ['Australia', 'diplomatic relation', 'Honduras'],
#    ['Australia', 'diplomatic relation', 'Hong Kong'],
#    ['Australia', 'diplomatic relation', 'India'],
#    ['Australia', 'diplomatic relation', 'Indonesia'],
#    ['Australia', 'diplomatic relation', 'Iran'],
#    ['Australia', 'diplomatic relation', 'Iraq'],
#    ['Australia', 'diplomatic relation', 'Ireland'],
#    ['Australia', 'diplomatic relation', 'Israel'],
#    ['Australia', 'diplomatic relation', 'Jamaica'],
#    ['Australia', 'diplomatic relation', 'Japan'],
#    ['Australia', 'diplomatic relation', 'Jordan'],
#    ['Australia', 'diplomatic relation', 'Kenya'],
#    ['Australia', 'diplomatic relation', 'Kosovo'],
#    ['Australia', 'diplomatic relation', 'Kuwait'],
#    ['Australia', 'diplomatic relation', 'Laos'],
#    ['Australia', 'diplomatic relation', 'Latvia'],
#    ['Australia', 'diplomatic relation', 'Lebanon'],
#    ['Australia', 'diplomatic relation', 'Lithuania'],
#    ['Australia', 'diplomatic relation', 'Malawi'],
#    ['Australia', 'diplomatic relation', 'Malaysia'],
#    ['Australia', 'diplomatic relation', 'Malta'],
#    ['Australia', 'diplomatic relation', 'Mauritius'],
#    ['Australia', 'diplomatic relation', 'Mexico'],
#    ['Australia', 'diplomatic relation', 'Mongolia'],
#    ['Australia', 'diplomatic relation', 'Mozambique'],
#    ['Australia', 'diplomatic relation', 'Myanmar'],
#    ['Australia', 'diplomatic relation', 'Namibia'],
#    ['Australia', 'diplomatic relation', 'Nauru'],
#    ['Australia', 'diplomatic relation', 'Nepal'],
#    ['Australia', 'diplomatic relation', 'Netherlands'],
#    ['Australia', 'diplomatic relation', 'New Caledonia'],
#    ['Australia', 'diplomatic relation', 'New Zealand'],
#    ['Australia', 'diplomatic relation', 'Nicaragua'],
#    ['Australia', 'diplomatic relation', 'Nigeria'],
#    ['Australia', 'diplomatic relation', 'North Korea'],
#    ['Australia', 'diplomatic relation', 'Norway'],
#    ['Australia', 'diplomatic relation', 'Pakistan'],
#    ['Australia', 'diplomatic relation', 'Palau'],
#    ['Australia', 'diplomatic relation', 'Palestinian National Authority'],
#    ['Australia', 'diplomatic relation', 'Papua New Guinea'],
#    ['Australia', 'diplomatic relation', 'Paraguay'],
#    ['Australia', 'diplomatic relation', "People's Republic of China"],
#    ['Australia', 'diplomatic relation', 'Peru'],
#    ['Australia', 'diplomatic relation', 'Philippines'],
#    ['Australia', 'diplomatic relation', 'Poland'],
#    ['Australia', 'diplomatic relation', 'Portugal'],
#    ['Australia', 'diplomatic relation', 'Qatar'],
#    ['Australia', 'diplomatic relation', 'Republic of Macedonia'],
#    ['Australia', 'diplomatic relation', 'Romania'],
#    ['Australia', 'diplomatic relation', 'Russia'],
#    ['Australia', 'diplomatic relation', 'Samoa'],
#    ['Australia', 'diplomatic relation', 'Saudi Arabia'],
#    ['Australia', 'diplomatic relation', 'Senegal'],
#    ['Australia', 'diplomatic relation', 'Serbia'],
#    ['Australia', 'diplomatic relation', 'Singapore'],
#    ['Australia', 'diplomatic relation', 'Slovenia'],
#    ['Australia', 'diplomatic relation', 'Solomon Islands'],
#    ['Australia', 'diplomatic relation', 'South Africa'],
#    ['Australia', 'diplomatic relation', 'South Korea'],
#    ['Australia', 'diplomatic relation', 'Spain'],
#    ['Australia', 'diplomatic relation', 'Sri Lanka'],
#    ['Australia', 'diplomatic relation', 'Sweden'],
#    ['Australia', 'diplomatic relation', 'Switzerland'],
#    ['Australia', 'diplomatic relation', 'Taiwan'],
#    ['Australia', 'diplomatic relation', 'Tanzania'],
#    ['Australia', 'diplomatic relation', 'Thailand'],
#    ['Australia', 'diplomatic relation', 'The Bahamas'],
#    ['Australia', 'diplomatic relation', 'Tonga'],
#    ['Australia', 'diplomatic relation', 'Trinidad and Tobago'],
#    ['Australia', 'diplomatic relation', 'Turkey'],
#    ['Australia', 'diplomatic relation', 'Uganda'],
#    ['Australia', 'diplomatic relation', 'Ukraine'],
#    ['Australia', 'diplomatic relation', 'United Arab Emirates'],
#    ['Australia', 'diplomatic relation', 'United Kingdom'],
#    ['Australia', 'diplomatic relation', 'United States of America'],
#    ['Australia', 'diplomatic relation', 'Uruguay'],
#    ['Australia', 'diplomatic relation', 'Vanuatu'],
#    ['Australia', 'diplomatic relation', 'Vietnam'],
#    ['Australia', 'diplomatic relation', 'Zambia'],
#    ['Australia', 'diplomatic relation', 'Zimbabwe'],
#    ['Australia', 'driving side', 'Australia'],
#    ['Australia', 'driving side', 'left'],
#    ['Australia', 'electrical plug type', 'AS/NZS 3112'],
#    ['Australia', 'emergency phone number', '000'],
#    ['Australia', 'ethnic group', 'Australia'],
#    ['Australia', 'ethnic group', 'Australians'],
#    ['Australia', 'ethnic group', 'Chinese people'],
#    ['Australia', 'ethnic group', 'Dutch people'],
#    ['Australia', 'ethnic group', 'English people'],
#    ['Australia', 'ethnic group', 'Germans'],
#    ['Australia', 'ethnic group', 'Greeks'],
#    ['Australia', 'ethnic group', 'Indian people'],
#    ['Australia', 'ethnic group', 'Irish people'],
#    ['Australia', 'ethnic group', 'Italians'],
#    ['Australia', 'ethnic group', 'Scottish people'],
#    ['Australia', 'ethnic group', 'indigenous Australians'],
#    ['Australia', 'executive body', 'Australia'],
#    ['Australia', 'executive body', 'Government of Australia'],
#    ['Australia', 'external data available at', 'Australia'],
#    ['Australia', 'flag', 'flag of Australia'],
#    ['Australia', 'follows', 'Australia'],
#    ['Australia', 'follows', 'United Kingdom of Great Britain and Ireland'],
#    ['Australia', 'geography of topic', 'Geography of Australia'],
#    ['Australia', 'has quality', 'Australia'],
#    ['Australia', 'has quality', 'Free country'],
#    ['Australia', 'head of government', 'Australia'],
#    ['Australia', 'head of government', 'Scott Morrison'],
#    ['Australia', 'head of state', 'Australia'],
#    ['Australia', 'head of state', 'Elizabeth II'],
#    ['Australia', 'head of state', 'Peter Cosgrove'],
#    ['Australia', 'highest judicial authority', 'High Court of Australia'],
#    ['Australia', 'highest point', 'Australia'],
#    ['Australia', 'highest point', 'Mawson Peak'],
#    ['Australia', 'history of topic', 'history of Australia'],
#    ['Australia', 'inception', 'Australia'],
#    ['Australia', 'inflation rate', 'Australia'],
#    ['Australia', 'instance of', 'Australia'],
#    ['Australia', 'instance of', 'sovereign state'],
#    ['Australia', 'language used', 'Arabic'],
#    ['Australia', 'language used', 'Bengali'],
#    ['Australia', 'language used', 'Cantonese'],
#    ['Australia', 'language used', 'Croatian'],
#    ['Australia', 'language used', 'English'],
#    ['Australia', 'language used', 'Filipino language'],
#    ['Australia', 'language used', 'French'],
#    ['Australia', 'language used', 'German'],
#    ['Australia', 'language used', 'Greek'],
#    ['Australia', 'language used', 'Gujarati'],
#    ['Australia', 'language used', 'Hindi'],
#    ['Australia', 'language used', 'Indonesian'],
#    ['Australia', 'language used', 'Italian'],
#    ['Australia', 'language used', 'Japanese'],
#    ['Australia', 'language used', 'Korean'],
#    ['Australia', 'language used', 'Macedonian'],
#    ['Australia', 'language used', 'Malayalam'],
#    ['Australia', 'language used', 'Mandarin Chinese'],
#    ['Australia', 'language used', 'Nepali'],
#    ['Australia', 'language used', 'Persian'],
#    ['Australia', 'language used', 'Punjabi'],
#    ['Australia', 'language used', 'Russian'],
#    ['Australia', 'language used', 'Serbian'],
#    ['Australia', 'language used', 'Sinhala'],
#    ['Australia', 'language used', 'Spanish'],
#    ['Australia', 'language used', 'Tagalog'],
#    ['Australia', 'language used', 'Tamil'],
#    ['Australia', 'language used', 'Thai'],
#    ['Australia', 'language used', 'Turkish'],
#    ['Australia', 'language used', 'Urdu'],
#    ['Australia', 'language used', 'Vietnamese'],
#    ['Australia', 'legislative body', 'Parliament of Australia'],
#    ['Australia', 'length', 'Australia'],
#    ['Australia', 'licence plate code', 'Australia'],
#    ['Australia', 'located in time zone', 'Australia'],
#    ['Australia', 'located next to body of water', 'Arafura Sea'],
#    ['Australia', 'located next to body of water', 'Australia'],
#    ['Australia', 'located next to body of water', 'Bass Strait'],
#    ['Australia', 'located next to body of water', 'Coral Sea'],
#    ['Australia', 'located next to body of water', 'Great Australian Bight'],
#    ['Australia', 'located next to body of water', 'Indian Ocean'],
#    ['Australia', 'located next to body of water', 'South Pacific'],
#    ['Australia', 'located next to body of water', 'Tasman Sea'],
#    ['Australia', 'located next to body of water', 'Timor Sea'],
#    ['Australia', 'main regulatory text', 'Australia'],
#    ['Australia', 'main regulatory text', 'Constitution of Australia'],
#    ['Australia', 'member of', 'ABCA Armies'],
#    ['Australia', 'member of', 'ANZUK'],
#    ['Australia', 'member of', 'ANZUS'],
#    ['Australia', 'member of', 'ASEAN'],
#    ['Australia', 'member of', 'AUSCANNZUKUS'],
#    ['Australia', 'member of', 'Air and Space Interoperability Council'],
#    ['Australia', 'member of', 'Asia-Pacific Economic Cooperation'],
#    ['Australia', 'member of', 'Asian Development Bank'],
#    ['Australia',
#     'member of',
#     'Association of Southeast Asian Nations Regional Forum'],
#    ['Australia', 'member of', 'Australia'],
# ...
#    ['Spain', 'BnF ID', 'Spain'],
#    ['Spain', 'CANTIC-ID', 'Spain'],
#    ['Spain', 'Commons gallery', 'Spain'],
#    ['Spain', 'DMOZ ID', 'Spain'],
#    ['Spain', 'Dagens Nyheter topic ID', 'Spain'],
#    ['Spain', 'Dewey Decimal Classification', 'Spain'],
#    ['Spain', 'Encyclopædia Britannica Online ID', 'Spain'],
#    ['Spain', 'FAST ID', 'Spain'],
#    ['Spain', 'FIPS 10-4 (countries and regions)', 'Spain'],
#    ['Spain', 'Freebase ID', 'Spain'],
#    ['Spain', 'GDP (PPP)', 'Spain'],
#    ['Spain', 'GeoNames ID', 'Spain'],
#    ['Spain', 'Great Russian Encyclopedia Online ID', 'Spain'],
#    ['Spain', 'Guardian topic ID', 'Spain'],
#    ['Spain', 'HDS ID', 'Spain'],
#    ['Spain', 'Human Development Index', 'Spain'],
#    ['Spain', 'INSEE countries and foreign territories code', 'Spain'],
#    ['Spain', 'IOC country code', 'Spain'],
#    ['Spain', 'IPA transcription', 'Spain'],
#    ['Spain', 'ISNI', 'Spain'],
#    ['Spain', 'ITU letter code', 'Spain'],
#    ['Spain', 'ITU/ISO/IEC object identifier', 'Spain'],
#    ['Spain', 'LAC ID', 'Spain'],
#    ['Spain', 'Le Monde diplomatique subject ID', 'Spain'],
#    ['Spain', 'M.49 code', 'Spain'],
#    ['Spain', 'MeSH ID', 'Spain'],
#    ['Spain', 'MusicBrainz area ID', 'Spain'],
#    ['Spain', 'NALT ID', 'Spain'],
#    ['Spain', 'NE.se ID', 'Spain'],
#    ['Spain', 'NKCR AUT ID', 'Spain'],
#    ['Spain', 'NLA (Australia) ID', 'Spain'],
#    ['Spain', 'NUTS code', 'Spain'],
#    ['Spain', 'NYT topic ID', 'Spain'],
#    ['Spain', 'National Archives Identifier', 'Spain'],
#    ['Spain', 'National Library of Israel ID', 'Spain'],
#    ['Spain', 'Nomisma ID', 'Spain'],
#    ['Spain', 'PPP GDP per capita', 'Spain'],
#    ['Spain', 'Quora topic ID', 'Spain'],
#    ['Spain', 'SELIBR', 'Spain'],
#    ['Spain', 'STW Thesaurus for Economics ID', 'Spain'],
#    ['Spain', 'SUDOC authorities', 'Spain'],
#    ['Spain', 'Statoids ID', 'Spain'],
#    ['Spain', 'TGN ID', 'Spain'],
#    ['Spain', 'UIC alphabetical country code', 'Spain'],
#    ['Spain', 'UIC numerical country code', 'Spain'],
#    ['Spain', 'UNESCO Thesaurus ID', 'Spain'],
#    ['Spain', 'Unicode character', 'Spain'],
#    ['Spain', 'WIPO ST.3', 'Spain'],
#    ['Spain', 'YSO ID', 'Spain'],
#    ['Spain', 'age of candidacy', 'Spain'],
#    ['Spain', 'age of consent', 'Spain'],
#    ['Spain', 'age of majority', 'Spain'],
#    ['Spain', 'anthem', 'Marcha Real'],
#    ['Spain', 'area', 'Spain'],
#    ['Spain', 'basic form of government', 'parliamentary monarchy'],
#    ['Spain', 'capital', 'Madrid'],
#    ['Spain', 'category for films shot at this location', 'Spain'],
#    ['Spain', 'category for people born here', 'Spain'],
#    ['Spain', 'category for people who died here', 'Spain'],
#    ['Spain', 'category of associated people', 'Spain'],
#    ['Spain', 'category of people buried here', 'Spain'],
#    ['Spain', 'coat of arms', 'coat of arms of Spain'],
#    ['Spain', 'coat of arms image', 'Spain'],
#    ['Spain', 'coextensive with', 'Spain'],
#    ['Spain', 'compulsory education (maximum age)', 'Spain'],
#    ['Spain', 'compulsory education (minimum age)', 'Spain'],
#    ['Spain', 'contains administrative territorial entity', 'Andalusia'],
#    ['Spain', 'contains administrative territorial entity', 'Aragon'],
#    ['Spain', 'contains administrative territorial entity', 'Asturias'],
#    ['Spain', 'contains administrative territorial entity', 'Balearic Islands'],
#    ['Spain', 'contains administrative territorial entity', 'Basque Country'],
#    ['Spain', 'contains administrative territorial entity', 'Canary Islands'],
#    ['Spain', 'contains administrative territorial entity', 'Cantabria'],
#    ['Spain', 'contains administrative territorial entity', 'Castile and León'],
#    ['Spain',
#     'contains administrative territorial entity',
#     'Castile-La Mancha'],
#    ['Spain', 'contains administrative territorial entity', 'Catalonia'],
#    ['Spain', 'contains administrative territorial entity', 'Ceuta'],
#    ['Spain',
#     'contains administrative territorial entity',
#     'Community of Madrid'],
#    ['Spain', 'contains administrative territorial entity', 'Extremadura'],
#    ['Spain', 'contains administrative territorial entity', 'Galicia'],
#    ['Spain', 'contains administrative territorial entity', 'La Rioja'],
#    ['Spain', 'contains administrative territorial entity', 'Melilla'],
#    ['Spain', 'contains administrative territorial entity', 'Navarre'],
#    ['Spain',
#     'contains administrative territorial entity',
#     'Plazas de soberanía'],
#    ['Spain', 'contains administrative territorial entity', 'Region of Murcia'],
#    ['Spain', 'contains administrative territorial entity', 'Spain'],
#    ['Spain',
#     'contains administrative territorial entity',
#     'Valencian Country'],
#    ['Spain', 'continent', 'Europe'],
#    ['Spain', 'continent', 'Spain'],
#    ['Spain', 'coordinate of easternmost point', 'Spain'],
#    ['Spain', 'coordinate of northernmost point', 'Spain'],
#    ['Spain', 'coordinate of southernmost point', 'Spain'],
#    ['Spain', 'coordinate of westernmost point', 'Spain'],
#    ['Spain', 'country', 'Spain'],
#    ['Spain', 'currency', 'Euro'],
#    ['Spain', 'currency', 'Spain'],
#    ['Spain', 'deepest point', 'Spain'],
#    ['Spain', 'demonym', 'Spain'],
#    ['Spain',
#     'described by source',
#     'Bible Encyclopedia of Archimandrite Nicephorus'],
#    ['Spain',
#     'described by source',
#     'Brockhaus and Efron Encyclopedic Dictionary'],
#    ['Spain', 'described by source', 'Catholic Encyclopedia'],
#    ['Spain',
#     'described by source',
#     'Jewish Encyclopedia of Brockhaus and Efron'],
#    ['Spain',
#     'described by source',
#     'Small Brockhaus and Efron Encyclopedic Dictionary'],
#    ['Spain', 'described by source', 'Spain'],
#    ['Spain', 'described by source', 'Sytin Military Encyclopedia'],
#    ['Spain', 'different from', 'Español'],
#    ['Spain', 'different from', 'Spain'],
#    ['Spain', 'diplomatic relation', 'Argentina'],
#    ['Spain', 'diplomatic relation', 'Australia'],
#    ['Spain', 'diplomatic relation', 'Bangladesh'],
#    ['Spain', 'diplomatic relation', 'Bosnia and Herzegovina'],
#    ['Spain', 'diplomatic relation', 'Brazil'],
#    ['Spain', 'diplomatic relation', 'Bulgaria'],
#    ['Spain', 'diplomatic relation', 'Canada'],
#    ['Spain', 'diplomatic relation', 'Chile'],
#    ['Spain', 'diplomatic relation', 'Colombia'],
#    ['Spain', 'diplomatic relation', 'Croatia'],
#    ['Spain', 'diplomatic relation', 'Cuba'],
#    ['Spain', 'diplomatic relation', 'Denmark'],
#    ['Spain', 'diplomatic relation', 'El Salvador'],
#    ['Spain', 'diplomatic relation', 'France'],
#    ['Spain', 'diplomatic relation', 'Georgia'],
#    ['Spain', 'diplomatic relation', 'Germany'],
#    ['Spain', 'diplomatic relation', 'Grecia'],
#    ['Spain', 'diplomatic relation', 'Greece'],
#    ['Spain', 'diplomatic relation', 'Holy See'],
#    ['Spain', 'diplomatic relation', 'Hungary'],
#    ['Spain', 'diplomatic relation', 'India'],
#    ['Spain', 'diplomatic relation', 'Indonesia'],
#    ['Spain', 'diplomatic relation', 'Jamaica'],
#    ['Spain', 'diplomatic relation', 'Japan'],
#    ['Spain', 'diplomatic relation', 'Kiribati'],
#    ['Spain', 'diplomatic relation', 'Malaysia'],
#    ['Spain', 'diplomatic relation', 'Malta'],
#    ['Spain', 'diplomatic relation', 'Mauritania'],
#    ['Spain', 'diplomatic relation', 'Mexico'],
#    ['Spain', 'diplomatic relation', 'Moldova'],
#    ['Spain', 'diplomatic relation', 'Morocco'],
#    ['Spain', 'diplomatic relation', 'New Zealand'],
#    ['Spain', 'diplomatic relation', 'Pakistan'],
#    ['Spain', 'diplomatic relation', 'Paraguay'],
#    ['Spain', 'diplomatic relation', "People's Republic of China"],
#    ['Spain', 'diplomatic relation', 'Peru'],
#    ['Spain', 'diplomatic relation', 'Philippines'],
#    ['Spain', 'diplomatic relation', 'Poland'],
#    ['Spain', 'diplomatic relation', 'Portugal'],
#    ['Spain', 'diplomatic relation', 'Romania'],
#    ['Spain', 'diplomatic relation', 'Russia'],
#    ['Spain', 'diplomatic relation', 'Serbia'],
#    ['Spain', 'diplomatic relation', 'Spain'],
#    ['Spain', 'diplomatic relation', 'Taiwan'],
#    ['Spain', 'diplomatic relation', 'Turkey'],
#    ['Spain', 'diplomatic relation', 'United Kingdom'],
#    ['Spain', 'diplomatic relation', 'Uruguay'],
#    ['Spain', 'diplomatic relation', 'Venezuela'],
#    ['Spain', 'diplomatic relation', 'Vietnam'],
#    ['Spain', 'driving side', 'Spain'],
#    ['Spain', 'driving side', 'right'],
#    ['Spain', 'electrical plug type', 'Europlug'],
#    ['Spain', 'electrical plug type', 'Schuko'],
#    ['Spain', 'electrical plug type', 'Spain'],
#    ['Spain', 'emergency phone number', '061'],
#    ['Spain', 'emergency phone number', '091'],
#    ['Spain', 'emergency phone number', '112'],
#    ['Spain', 'emergency phone number', 'Spain'],
#    ['Spain', 'ethnic group', 'Spain'],
#    ['Spain', 'ethnic group', 'Spaniards'],
#    ['Spain', 'executive body', 'Government of Spain'],
#    ['Spain', 'executive body', 'Spain'],
#    ['Spain', 'flag', 'flag of Spain'],
#    ['Spain', 'flag image', 'Spain'],
#    ['Spain', 'geography of topic', 'Spain'],
#    ['Spain', 'geography of topic', 'geography of Spain'],
#    ['Spain', 'geoshape', 'Spain'],
#    ['Spain', 'has parts of the class', 'Spain'],
#    ['Spain', 'has parts of the class', 'autonomous city of Spain'],
#    ['Spain', 'has parts of the class', 'autonomous community of Spain'],
#    ['Spain', 'has parts of the class', 'municipality of Spain'],
#    ['Spain', 'has parts of the class', 'province of Spain'],
#    ['Spain', 'has quality', 'Free country'],
#    ['Spain', 'has quality', 'Spain'],
#    ['Spain', 'head of government', 'Pedro Sánchez Pérez-Castejón'],
#    ['Spain', 'head of government', 'Spain'],
#    ['Spain', 'head of state', 'Felipe VI of Spain'],
#    ['Spain', 'head of state', 'Spain'],
#    ['Spain', 'highest judicial authority', 'Constitutional Court of Spain'],
#    ['Spain', 'highest judicial authority', 'Supreme Court of Spain'],
#    ['Spain', 'highest point', 'Spain'],
#    ['Spain', 'highest point', 'Teide'],
#    ['Spain', 'history of topic', 'Spain'],
#    ['Spain', 'history of topic', 'history of Spain'],
#    ['Spain', 'inception', 'Spain'],
#    ['Spain', 'inflation rate', 'Spain'],
#    ['Spain', 'instance of', 'Spain'],
#    ['Spain', 'instance of', 'sovereign state'],
#    ['Spain', 'legislative body', 'Cortes Generales'],
#    ['Spain', 'licence plate code', 'Spain'],
#    ['Spain', 'life expectancy', 'Spain'],
#    ['Spain', 'located in time zone', 'Spain'],
#    ['Spain', 'located next to body of water', 'Alboran Sea'],
#    ['Spain', 'located next to body of water', 'Atlantic Ocean'],
#    ['Spain', 'located next to body of water', 'Cantabrian Sea'],
#    ['Spain', 'located next to body of water', 'Mediterranean Sea'],
#    ['Spain', 'located next to body of water', 'Spain'],
#    ['Spain', 'located on terrain feature', 'Africa'],
#    ['Spain', 'located on terrain feature', 'Iberian Peninsula'],
#    ['Spain', 'located on terrain feature', 'Spain'],
#    ['Spain', 'location map', 'Spain'],
#    ['Spain', 'locator map image', 'Spain'],
#    ['Spain', 'mains voltage', 'Spain'],
#    ['Spain', 'maritime identification digits', 'Spain'],
#    ['Spain', 'marriageable age', 'Spain'],
#    ['Spain', 'median income', 'Spain'],
#    ['Spain', 'member of', 'African Development Bank'],
#    ['Spain', 'member of', 'Asian Development Bank'],
#    ['Spain', 'member of', 'Australia Group'],
#    ['Spain', 'member of', 'Central American Bank for Economic Integration'],
#    ['Spain', 'member of', 'Council of Europe'],
#    ['Spain', 'member of', 'Eurocontrol'],
#    ['Spain', 'member of', 'European Air Transport Command'],
#    ['Spain', 'member of', 'European Southern Observatory'],
#    ['Spain', 'member of', 'European Space Agency'],
#    ['Spain', 'member of', 'European Union'],
#    ['Spain', 'member of', 'Group on Earth Observations'],
#    ['Spain',
#     'member of',
#     'International Bank for Reconstruction and Development'],
#    ['Spain',
#     'member of',
#     'International Centre for Settlement of Investment Disputes'],
#    ['Spain', 'member of', 'International Development Association'],
#    ['Spain', 'member of', 'International Energy Agency'],
#    ['Spain', 'member of', 'International Finance Corporation'],
#    ['Spain', 'member of', 'International Hydrographic Organization'],
#    ['Spain', 'member of', 'Interpol'],
#    ['Spain', 'member of', 'League of Nations'],
#    ['Spain', 'member of', 'Missile Technology Control Regime'],
#    ['Spain', 'member of', 'Movement Coordination Centre Europe'],
#    ['Spain', 'member of', 'Multilateral Investment Guarantee Agency'],
#    ['Spain', 'member of', 'North Atlantic Treaty Organisation'],
#    ['Spain', 'member of', 'Nuclear Suppliers Group'],
#    ['Spain', 'member of', 'Organisation for Joint Armament Cooperation'],
#    ['Spain',
#     'member of',
#     'Organisation for the Prohibition of Chemical Weapons'],
#    ['Spain',
#     'member of',
#     'Organization for Economic Co-operation and Development'],
#    ['Spain',
#     'member of',
#     'Organization for Security and Co-operation in Europe'],
#    ['Spain', 'member of', 'Organization of Ibero-American States'],
#    ['Spain', 'member of', 'Spain'],
#    ['Spain', 'member of', 'Treaty on Open Skies'],
#    ['Spain', 'member of', 'United Nations'],
#    ['Spain',
#     'member of',
#     'United Nations Educational, Scientific and Cultural Organization'],
#    ['Spain', 'member of', 'United Nations Security Council'],
#    ['Spain', 'member of', 'World Trade Organization'],
#    ['Spain', 'mobile country code', 'Spain'],
#    ['Spain', 'motto', 'Plus ultra'],
#    ['Spain', 'motto', 'Spain'],
#    ['Spain', 'nominal GDP', 'Spain'],
#    ['Spain', 'nominal GDP per capita', 'Spain'],
#    ['Spain', 'number of out of school children', 'Spain'],
#    ['Spain', 'office held by head of government', 'Prime Minister of Spain'],
#    ['Spain', 'office held by head of government', 'Spain'],
#    ['Spain', 'office held by head of state', 'King of Spain'],
#    ['Spain', 'office held by head of state', 'Spain'],
#    ['Spain', 'official language', 'Spanish'],
#    ['Spain', 'official name', 'Spain'],
#    ['Spain', 'official religion', 'Non-denominational'],
#    ['Spain', 'official religion', 'Spain'],
#    ['Spain', 'official website', 'Spain'],
#    ['Spain', 'page banner', 'Spain'],
#    ['Spain', 'participant of', 'American Revolutionary War'],
#    ['Spain', 'participant of', 'Battle of Porto Bello'],
#    ['Spain', 'participant of', 'Franco-Spanish War (1635–1659)'],
#    ['Spain', 'participant of', 'Spain'],
#    ['Spain', 'participant of', "War of Jenkins' Ear"],
#    ['Spain', 'permanent duplicated item', 'Spain'],
#    ['Spain', 'population', 'Spain'],
#    ['Spain', 'public holiday', 'Assumption of Mary'],
#    ['Spain', 'public holiday', 'Christmas'],
#    ['Spain', 'public holiday', 'Epiphany'],
#    ['Spain', 'public holiday', 'Fiesta Nacional de España'],
#    ['Spain', 'public holiday', 'Good Friday'],
#    ['Spain', 'public holiday', 'Immaculate Conception of Mary'],
#    ['Spain', 'public holiday', "International Workers' Day"],
#    ['Spain', 'public holiday', "New Year's Day"],
#    ['Spain', 'public holiday', 'Spain'],
#    ['Spain', 'real gross domestic product growth rate', 'Spain'],
#    ['Spain', 'replaces', 'Monarquía Hispánica'],
#    ['Spain', 'replaces', 'Spain'],
#    ['Spain', 'retirement age', 'Spain'],
#    ['Spain', 'shares border with', 'Andorra'],
#    ['Spain', 'shares border with', 'France'],
#    ['Spain', 'shares border with', 'Gibraltar'],
#    ['Spain', 'shares border with', 'Morocco'],
#    ['Spain', 'shares border with', 'Portugal'],
#    ['Spain', 'shares border with', 'Spain'],
#    ['Spain', 'short name', 'Spain'],
#    ['Spain', 'significant event', 'Nueva Planta decrees'],
#    ['Spain', 'significant event', 'Spain'],
#    ['Spain', 'significant event', 'Spanish Constitution of 1812'],
#    ['Spain', 'significant event', 'Spanish Constitution of 1931'],
#    ['Spain', 'significant event', 'Spanish Constitution of 1978'],
#    ['Spain', 'significant event', 'Spanish transition to democracy'],
#    ['Spain', 'subreddit', 'Spain'],
#    ['Spain', 'top-level internet domain', '.es'],
#    ['Spain', "topic's main Wikimedia portal", 'Spain'],
#    ['Spain', "topic's main category", 'Spain'],
#    ['Spain', 'total reserves', 'Spain'],
#    ['Spain', 'unemployment rate', 'Spain']],
#   'result': 0}]

# %%
from keras.layers.embeddings import Embedding
def pretrained_embedding_layer(word_to_vec_map, words_to_index):
    """
    Creates a Keras Embedding() layer and loads in pre-trained GloVe 50-dimensional vectors.
    Arguments:
    word_to_vec_map -- dictionary mapping words to their GloVe vector representation.
    word_to_index -- dictionary mapping from words to their indices in the vocabulary (400,001 words)

    Returns:
    embedding_layer -- pretrained layer Keras instance
    """
    vocab_len = len(words_to_index) + 1                  # adding 1 to fit Keras embedding (requirement)
    emb_dim = word_to_vec_map["cucumber"].shape[0]      # define dimensionality of your GloVe word vectors (= 50)
    
    # Initialize the embedding matrix as a numpy array of zeros of shape (vocab_len, dimensions of word vectors = emb_dim)
    emb_matrix = np.zeros((vocab_len, emb_dim))
    
    # Set each row "index" of the embedding matrix to be the word vector representation of the "index"th word of the vocabulary
    for word, index in words_to_index.items():
        emb_matrix[index, :] = word_to_vec_map[word]

    # Define Keras embedding layer with the correct output/input sizes, make it trainable. Use Embedding(...). Make sure to set trainable=False. 
    embedding_layer = Embedding(vocab_len, emb_dim, trainable=False, name="embedding")

    # Build the embedding layer, it is required before setting the weights of the embedding layer. Do not modify the "None".
    embedding_layer.build((None,))
    
    # Set the weights of the embedding layer to the embedding matrix. Your layer is now pretrained.
    embedding_layer.set_weights([emb_matrix])
    
    return embedding_layer

# %%
embedding_layer = pretrained_embedding_layer(word_to_vec_map, words_to_index)
print("weights[0][1][3] =", embedding_layer.get_weights()[0][1][3])
# Out:
# weights[0][1][3] = -0.3403

# %%
import numpy as np
np.random.seed(0)
from keras.models import Model
from keras.backend import mean, sum
from keras.layers import Dense, Input, Dropout, LSTM, Activation, GRU, Concatenate, Multiply, Reshape
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.initializers import glorot_uniform
from keras.layers import Lambda
np.random.seed(1)
from keras.models import Sequential

def myUnstack(xin):
    return tf.unstack(xin, axis=1)

def ned_model(input_shape, mask_shape, triplets_shape, word_to_vec_map, word_to_index):
    """
    Function creating the context-vector-generator model's graph.
    
    Arguments:
    input_shape -- shape of the input, usually (max_len,)
    word_to_vec_map -- dictionary mapping every word in a vocabulary into its 50-dimensional vector representation
    word_to_index -- dictionary mapping from words to their indices in the vocabulary (400,001 words)

    Returns:
    model -- a model instance in Keras
    """

    # Create all the layers
    embedding_layer = pretrained_embedding_layer(word_to_vec_map, word_to_index)
    sentence_gru1 = GRU( 50, return_sequences=True, name="ASentence_GRU1")
    sentence_gru2 = GRU( 50, return_sequences=True, name="ASentence_GRU2")
    triplets_gru1 = GRU( 50, batch_size=500, input_shape=triplets_shape, return_sequences=True, name="ATriplets_GRU1")
    triplets_gru2 = GRU( 50, return_sequences=True, name="ATriplets_GRU2")
    mean_layer = Lambda(lambda xin: mean(xin, axis=1), name="AMeanLayer")
    unstack_layer = Lambda(lambda xin: myUnstack(xin), name="AUnstackLayer")
    
    # sentence inputs
    sentence_indices = Input(shape=input_shape, dtype='int32', name="sentence_indices")   
    sentence_masks = Input(shape=mask_shape, dtype='float32', name="sentence_masks")
    
    # sentence embeddings
    sentence_embeddings = embedding_layer(sentence_indices)       
    X_sentence = sentence_gru2(sentence_gru1(sentence_embeddings))
    X_sentence = Multiply()([sentence_masks, X_sentence])
    X_sentence = mean_layer(X_sentence)
    
    #X_sentence = mean(X_sentence, axis=1) #1*60*50 if axis=0 it means it took average of all the X it recieved in this batch
    
    #X_sentence = tf.reduce_mean(tf.multiply(sentence_masks, X_sentence), axis=0)
    
    # triplets input
    triplets_indices = Input(shape=triplets_shape, dtype='int32', name="Atriplets_indices")   
   
    # triplets embeddings
    triplet_embeddings = embedding_layer(triplets_indices) 
    print(triplet_embeddings.get_shape())
    #r = Reshape((-1, 500, 300))(triplet_embeddings)#data.reshape((-1,20))
    unstacked_embeddings = unstack_layer(triplet_embeddings)
    o = Concatenate(axis=1)(unstacked_embeddings) # 0=(,60,50), 1 = (, 30000, 50), 2=(, 60, 25000)
    X_triplets = mean_layer(triplets_gru2(triplets_gru1(o)))
    
    # ATriplets_GRU1 (GRU)            (None, 60, 50)       3757650     concatenate_19[0][0]             for axis2 concatenate
    #outputs = [[[50]]]
#     embeddings = tf.unstack(triplet_embeddings, axis=1)
    #for index in range(len(unstacked_embeddings)):
     # outputs += triplets_gru1(unstacked_embeddings[index])
    
    #tf.keras.backend.stack(x,axis=0)

    #mean_outputs = mean_layer(outputs) # using it 
#     print(outputs.get_shape())
    
#     # now concat triplet and sentence embeddings - how to do?
    X_concatenated = Concatenate()([X_sentence, X_triplets])
    
#     # Propagate X through a Dense layer with softmax activation to get back a batch of 20-dimensional vectors.
    X_concatenated = Dense(20, activation='relu', name="Dense20")(X_concatenated)

    Y_pred = Dense(1, activation='sigmoid', name="Dense1")(X_concatenated)
    
    # Add a softmax activation
    #Y_pred = Activation('softmax')(X_concatenated)

    # Create Model instance which converts sentence_indices into X.
    model = Model(inputs=[sentence_indices, sentence_masks, triplets_indices], outputs=Y_pred)
#    model = Model(inputs=[triplets_indices], outputs=Y_pred)
  
  # talk 
    
    return model
# Out:
# Using TensorFlow backend.

# %%
# create inputs for model
def generate_model_inputs(inputFile, mask_dim):
    inputData = read_triplets(inputFile)
    triplet_indices = []
    Y = []
    sentence_indices = []
    sentence_masks = []
    for data in inputData:
        sentence_indices.append(sentences_to_indices(np.asarray([data['question']]),words_to_index, max_len = 60))
        sentence_masks.append(sentence_to_target_mask(data['name'], data['question'], dim=mask_dim))
        if 'wrong_triplets' in data:
            #print("wrong")
            triplet_indices.append(triplets_to_indices(data['wrong_triplets']))
            Y.append(0)
        else:
            #print("here")
            triplet_indices.append(triplets_to_indices(data['correct_triplets']))
            Y.append(1)
    return triplet_indices, Y, sentence_indices, sentence_masks

triplet_indices, Y, sentence_indices, sentence_masks = generate_model_inputs('/Users/surthi/Documents/cs230project/data_wiki_handshake/input_w_wiki_1.ipwk', mask_dim=50)
print(np.asarray(triplet_indices).shape)
print(np.asarray(Y).shape)
print(np.squeeze(np.asarray(sentence_indices)).shape)
print(np.asarray(sentence_masks).shape)
# Out:
# 10
# 20
# (20, 500, 60)
# (20,)
# (20, 60)
# (20,)

# %%
maxWordsPerSentence=60
maxTriplets=500
model = ned_model((maxWordsPerSentence,), (maxWordsPerSentence,50,), (maxTriplets, maxWordsPerSentence,), word_to_vec_map, words_to_index)
model.summary()
# Out:
# (?, 500, 60, 50)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sentence_indices (InputLayer)   (None, 60)           0
# __________________________________________________________________________________________________
# Atriplets_indices (InputLayer)  (None, 500, 60)      0
# __________________________________________________________________________________________________
# embedding (Embedding)           multiple             20000050    sentence_indices[0][0]
#                                                                  Atriplets_indices[0][0]
# __________________________________________________________________________________________________
# AUnstackLayer (Lambda)          [(None, 60, 50), (No 0           embedding[1][0]
# __________________________________________________________________________________________________
# ASentence_GRU1 (GRU)            (None, 60, 50)       15150       embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 30000, 50)    0           AUnstackLayer[0][0]
#                                                                  AUnstackLayer[0][1]
#                                                                  AUnstackLayer[0][2]
#                                                                  AUnstackLayer[0][3]
#                                                                  AUnstackLayer[0][4]
#                                                                  AUnstackLayer[0][5]
#                                                                  AUnstackLayer[0][6]
#                                                                  AUnstackLayer[0][7]
#                                                                  AUnstackLayer[0][8]
#                                                                  AUnstackLayer[0][9]
#                                                                  AUnstackLayer[0][10]
#                                                                  AUnstackLayer[0][11]
#                                                                  AUnstackLayer[0][12]
#                                                                  AUnstackLayer[0][13]
#                                                                  AUnstackLayer[0][14]
#                                                                  AUnstackLayer[0][15]
#                                                                  AUnstackLayer[0][16]
#                                                                  AUnstackLayer[0][17]
#                                                                  AUnstackLayer[0][18]
#                                                                  AUnstackLayer[0][19]
#                                                                  AUnstackLayer[0][20]
#                                                                  AUnstackLayer[0][21]
#                                                                  AUnstackLayer[0][22]
#                                                                  AUnstackLayer[0][23]
#                                                                  AUnstackLayer[0][24]
#                                                                  AUnstackLayer[0][25]
#                                                                  AUnstackLayer[0][26]
#                                                                  AUnstackLayer[0][27]
#                                                                  AUnstackLayer[0][28]
#                                                                  AUnstackLayer[0][29]
#                                                                  AUnstackLayer[0][30]
#                                                                  AUnstackLayer[0][31]
#                                                                  AUnstackLayer[0][32]
#                                                                  AUnstackLayer[0][33]
#                                                                  AUnstackLayer[0][34]
#                                                                  AUnstackLayer[0][35]
#                                                                  AUnstackLayer[0][36]
#                                                                  AUnstackLayer[0][37]
#                                                                  AUnstackLayer[0][38]
#                                                                  AUnstackLayer[0][39]
#                                                                  AUnstackLayer[0][40]
#                                                                  AUnstackLayer[0][41]
#                                                                  AUnstackLayer[0][42]
#                                                                  AUnstackLayer[0][43]
#                                                                  AUnstackLayer[0][44]
#                                                                  AUnstackLayer[0][45]
#                                                                  AUnstackLayer[0][46]
#                                                                  AUnstackLayer[0][47]
#                                                                  AUnstackLayer[0][48]
#                                                                  AUnstackLayer[0][49]
#                                                                  AUnstackLayer[0][50]
#                                                                  AUnstackLayer[0][51]
#                                                                  AUnstackLayer[0][52]
#                                                                  AUnstackLayer[0][53]
#                                                                  AUnstackLayer[0][54]
#                                                                  AUnstackLayer[0][55]
#                                                                  AUnstackLayer[0][56]
#                                                                  AUnstackLayer[0][57]
#                                                                  AUnstackLayer[0][58]
#                                                                  AUnstackLayer[0][59]
#                                                                  AUnstackLayer[0][60]
#                                                                  AUnstackLayer[0][61]
#                                                                  AUnstackLayer[0][62]
#                                                                  AUnstackLayer[0][63]
#                                                                  AUnstackLayer[0][64]
#                                                                  AUnstackLayer[0][65]
#                                                                  AUnstackLayer[0][66]
#                                                                  AUnstackLayer[0][67]
#                                                                  AUnstackLayer[0][68]
#                                                                  AUnstackLayer[0][69]
#                                                                  AUnstackLayer[0][70]
#                                                                  AUnstackLayer[0][71]
#                                                                  AUnstackLayer[0][72]
#                                                                  AUnstackLayer[0][73]
#                                                                  AUnstackLayer[0][74]
#                                                                  AUnstackLayer[0][75]
#                                                                  AUnstackLayer[0][76]
#                                                                  AUnstackLayer[0][77]
#                                                                  AUnstackLayer[0][78]
#                                                                  AUnstackLayer[0][79]
#                                                                  AUnstackLayer[0][80]
#                                                                  AUnstackLayer[0][81]
#                                                                  AUnstackLayer[0][82]
#                                                                  AUnstackLayer[0][83]
#                                                                  AUnstackLayer[0][84]
#                                                                  AUnstackLayer[0][85]
#                                                                  AUnstackLayer[0][86]
#                                                                  AUnstackLayer[0][87]
#                                                                  AUnstackLayer[0][88]
#                                                                  AUnstackLayer[0][89]
#                                                                  AUnstackLayer[0][90]
#                                                                  AUnstackLayer[0][91]
#                                                                  AUnstackLayer[0][92]
#                                                                  AUnstackLayer[0][93]
#                                                                  AUnstackLayer[0][94]
#                                                                  AUnstackLayer[0][95]
#                                                                  AUnstackLayer[0][96]
#                                                                  AUnstackLayer[0][97]
#                                                                  AUnstackLayer[0][98]
#                                                                  AUnstackLayer[0][99]
#                                                                  AUnstackLayer[0][100]
#                                                                  AUnstackLayer[0][101]
#                                                                  AUnstackLayer[0][102]
#                                                                  AUnstackLayer[0][103]
#                                                                  AUnstackLayer[0][104]
#                                                                  AUnstackLayer[0][105]
#                                                                  AUnstackLayer[0][106]
#                                                                  AUnstackLayer[0][107]
#                                                                  AUnstackLayer[0][108]
#                                                                  AUnstackLayer[0][109]
#                                                                  AUnstackLayer[0][110]
#                                                                  AUnstackLayer[0][111]
#                                                                  AUnstackLayer[0][112]
#                                                                  AUnstackLayer[0][113]
#                                                                  AUnstackLayer[0][114]
#                                                                  AUnstackLayer[0][115]
#                                                                  AUnstackLayer[0][116]
#                                                                  AUnstackLayer[0][117]
#                                                                  AUnstackLayer[0][118]
#                                                                  AUnstackLayer[0][119]
#                                                                  AUnstackLayer[0][120]
#                                                                  AUnstackLayer[0][121]
#                                                                  AUnstackLayer[0][122]
#                                                                  AUnstackLayer[0][123]
#                                                                  AUnstackLayer[0][124]
#                                                                  AUnstackLayer[0][125]
#                                                                  AUnstackLayer[0][126]
#                                                                  AUnstackLayer[0][127]
#                                                                  AUnstackLayer[0][128]
#                                                                  AUnstackLayer[0][129]
#                                                                  AUnstackLayer[0][130]
#                                                                  AUnstackLayer[0][131]
#                                                                  AUnstackLayer[0][132]
#                                                                  AUnstackLayer[0][133]
#                                                                  AUnstackLayer[0][134]
#                                                                  AUnstackLayer[0][135]
#                                                                  AUnstackLayer[0][136]
#                                                                  AUnstackLayer[0][137]
#                                                                  AUnstackLayer[0][138]
#                                                                  AUnstackLayer[0][139]
#                                                                  AUnstackLayer[0][140]
#                                                                  AUnstackLayer[0][141]
#                                                                  AUnstackLayer[0][142]
#                                                                  AUnstackLayer[0][143]
#                                                                  AUnstackLayer[0][144]
#                                                                  AUnstackLayer[0][145]
#                                                                  AUnstackLayer[0][146]
#                                                                  AUnstackLayer[0][147]
#                                                                  AUnstackLayer[0][148]
#                                                                  AUnstackLayer[0][149]
#                                                                  AUnstackLayer[0][150]
#                                                                  AUnstackLayer[0][151]
#                                                                  AUnstackLayer[0][152]
#                                                                  AUnstackLayer[0][153]
#                                                                  AUnstackLayer[0][154]
#                                                                  AUnstackLayer[0][155]
#                                                                  AUnstackLayer[0][156]
#                                                                  AUnstackLayer[0][157]
#                                                                  AUnstackLayer[0][158]
#                                                                  AUnstackLayer[0][159]
#                                                                  AUnstackLayer[0][160]
#                                                                  AUnstackLayer[0][161]
#                                                                  AUnstackLayer[0][162]
#                                                                  AUnstackLayer[0][163]
#                                                                  AUnstackLayer[0][164]
#                                                                  AUnstackLayer[0][165]
#                                                                  AUnstackLayer[0][166]
#                                                                  AUnstackLayer[0][167]
#                                                                  AUnstackLayer[0][168]
#                                                                  AUnstackLayer[0][169]
#                                                                  AUnstackLayer[0][170]
#                                                                  AUnstackLayer[0][171]
#                                                                  AUnstackLayer[0][172]
#                                                                  AUnstackLayer[0][173]
#                                                                  AUnstackLayer[0][174]
#                                                                  AUnstackLayer[0][175]
#                                                                  AUnstackLayer[0][176]
#                                                                  AUnstackLayer[0][177]
#                                                                  AUnstackLayer[0][178]
#                                                                  AUnstackLayer[0][179]
#                                                                  AUnstackLayer[0][180]
#                                                                  AUnstackLayer[0][181]
#                                                                  AUnstackLayer[0][182]
#                                                                  AUnstackLayer[0][183]
#                                                                  AUnstackLayer[0][184]
#                                                                  AUnstackLayer[0][185]
#                                                                  AUnstackLayer[0][186]
#                                                                  AUnstackLayer[0][187]
#                                                                  AUnstackLayer[0][188]
#                                                                  AUnstackLayer[0][189]
#                                                                  AUnstackLayer[0][190]
#                                                                  AUnstackLayer[0][191]
#                                                                  AUnstackLayer[0][192]
#                                                                  AUnstackLayer[0][193]
#                                                                  AUnstackLayer[0][194]
#                                                                  AUnstackLayer[0][195]
#                                                                  AUnstackLayer[0][196]
#                                                                  AUnstackLayer[0][197]
#                                                                  AUnstackLayer[0][198]
#                                                                  AUnstackLayer[0][199]
#                                                                  AUnstackLayer[0][200]
#                                                                  AUnstackLayer[0][201]
#                                                                  AUnstackLayer[0][202]
#                                                                  AUnstackLayer[0][203]
#                                                                  AUnstackLayer[0][204]
#                                                                  AUnstackLayer[0][205]
#                                                                  AUnstackLayer[0][206]
#                                                                  AUnstackLayer[0][207]
#                                                                  AUnstackLayer[0][208]
#                                                                  AUnstackLayer[0][209]
#                                                                  AUnstackLayer[0][210]
#                                                                  AUnstackLayer[0][211]
#                                                                  AUnstackLayer[0][212]
#                                                                  AUnstackLayer[0][213]
#                                                                  AUnstackLayer[0][214]
#                                                                  AUnstackLayer[0][215]
#                                                                  AUnstackLayer[0][216]
#                                                                  AUnstackLayer[0][217]
#                                                                  AUnstackLayer[0][218]
#                                                                  AUnstackLayer[0][219]
#                                                                  AUnstackLayer[0][220]
#                                                                  AUnstackLayer[0][221]
#                                                                  AUnstackLayer[0][222]
#                                                                  AUnstackLayer[0][223]
#                                                                  AUnstackLayer[0][224]
#                                                                  AUnstackLayer[0][225]
#                                                                  AUnstackLayer[0][226]
#                                                                  AUnstackLayer[0][227]
#                                                                  AUnstackLayer[0][228]
#                                                                  AUnstackLayer[0][229]
#                                                                  AUnstackLayer[0][230]
#                                                                  AUnstackLayer[0][231]
#                                                                  AUnstackLayer[0][232]
#                                                                  AUnstackLayer[0][233]
#                                                                  AUnstackLayer[0][234]
#                                                                  AUnstackLayer[0][235]
#                                                                  AUnstackLayer[0][236]
#                                                                  AUnstackLayer[0][237]
#                                                                  AUnstackLayer[0][238]
#                                                                  AUnstackLayer[0][239]
#                                                                  AUnstackLayer[0][240]
#                                                                  AUnstackLayer[0][241]
#                                                                  AUnstackLayer[0][242]
#                                                                  AUnstackLayer[0][243]
#                                                                  AUnstackLayer[0][244]
#                                                                  AUnstackLayer[0][245]
#                                                                  AUnstackLayer[0][246]
#                                                                  AUnstackLayer[0][247]
#                                                                  AUnstackLayer[0][248]
#                                                                  AUnstackLayer[0][249]
#                                                                  AUnstackLayer[0][250]
#                                                                  AUnstackLayer[0][251]
#                                                                  AUnstackLayer[0][252]
#                                                                  AUnstackLayer[0][253]
#                                                                  AUnstackLayer[0][254]
#                                                                  AUnstackLayer[0][255]
#                                                                  AUnstackLayer[0][256]
#                                                                  AUnstackLayer[0][257]
#                                                                  AUnstackLayer[0][258]
#                                                                  AUnstackLayer[0][259]
#                                                                  AUnstackLayer[0][260]
#                                                                  AUnstackLayer[0][261]
#                                                                  AUnstackLayer[0][262]
#                                                                  AUnstackLayer[0][263]
#                                                                  AUnstackLayer[0][264]
#                                                                  AUnstackLayer[0][265]
#                                                                  AUnstackLayer[0][266]
#                                                                  AUnstackLayer[0][267]
#                                                                  AUnstackLayer[0][268]
#                                                                  AUnstackLayer[0][269]
#                                                                  AUnstackLayer[0][270]
#                                                                  AUnstackLayer[0][271]
#                                                                  AUnstackLayer[0][272]
#                                                                  AUnstackLayer[0][273]
#                                                                  AUnstackLayer[0][274]
#                                                                  AUnstackLayer[0][275]
#                                                                  AUnstackLayer[0][276]
#                                                                  AUnstackLayer[0][277]
#                                                                  AUnstackLayer[0][278]
#                                                                  AUnstackLayer[0][279]
#                                                                  AUnstackLayer[0][280]
#                                                                  AUnstackLayer[0][281]
#                                                                  AUnstackLayer[0][282]
#                                                                  AUnstackLayer[0][283]
#                                                                  AUnstackLayer[0][284]
#                                                                  AUnstackLayer[0][285]
#                                                                  AUnstackLayer[0][286]
#                                                                  AUnstackLayer[0][287]
#                                                                  AUnstackLayer[0][288]
#                                                                  AUnstackLayer[0][289]
#                                                                  AUnstackLayer[0][290]
#                                                                  AUnstackLayer[0][291]
#                                                                  AUnstackLayer[0][292]
#                                                                  AUnstackLayer[0][293]
#                                                                  AUnstackLayer[0][294]
#                                                                  AUnstackLayer[0][295]
#                                                                  AUnstackLayer[0][296]
#                                                                  AUnstackLayer[0][297]
#                                                                  AUnstackLayer[0][298]
#                                                                  AUnstackLayer[0][299]
#                                                                  AUnstackLayer[0][300]
#                                                                  AUnstackLayer[0][301]
#                                                                  AUnstackLayer[0][302]
#                                                                  AUnstackLayer[0][303]
#                                                                  AUnstackLayer[0][304]
#                                                                  AUnstackLayer[0][305]
#                                                                  AUnstackLayer[0][306]
#                                                                  AUnstackLayer[0][307]
#                                                                  AUnstackLayer[0][308]
#                                                                  AUnstackLayer[0][309]
#                                                                  AUnstackLayer[0][310]
#                                                                  AUnstackLayer[0][311]
#                                                                  AUnstackLayer[0][312]
#                                                                  AUnstackLayer[0][313]
#                                                                  AUnstackLayer[0][314]
#                                                                  AUnstackLayer[0][315]
#                                                                  AUnstackLayer[0][316]
#                                                                  AUnstackLayer[0][317]
#                                                                  AUnstackLayer[0][318]
#                                                                  AUnstackLayer[0][319]
#                                                                  AUnstackLayer[0][320]
#                                                                  AUnstackLayer[0][321]
#                                                                  AUnstackLayer[0][322]
#                                                                  AUnstackLayer[0][323]
#                                                                  AUnstackLayer[0][324]
#                                                                  AUnstackLayer[0][325]
#                                                                  AUnstackLayer[0][326]
#                                                                  AUnstackLayer[0][327]
#                                                                  AUnstackLayer[0][328]
#                                                                  AUnstackLayer[0][329]
#                                                                  AUnstackLayer[0][330]
#                                                                  AUnstackLayer[0][331]
#                                                                  AUnstackLayer[0][332]
#                                                                  AUnstackLayer[0][333]
#                                                                  AUnstackLayer[0][334]
#                                                                  AUnstackLayer[0][335]
#                                                                  AUnstackLayer[0][336]
#                                                                  AUnstackLayer[0][337]
#                                                                  AUnstackLayer[0][338]
#                                                                  AUnstackLayer[0][339]
#                                                                  AUnstackLayer[0][340]
#                                                                  AUnstackLayer[0][341]
#                                                                  AUnstackLayer[0][342]
#                                                                  AUnstackLayer[0][343]
#                                                                  AUnstackLayer[0][344]
#                                                                  AUnstackLayer[0][345]
#                                                                  AUnstackLayer[0][346]
#                                                                  AUnstackLayer[0][347]
#                                                                  AUnstackLayer[0][348]
#                                                                  AUnstackLayer[0][349]
#                                                                  AUnstackLayer[0][350]
#                                                                  AUnstackLayer[0][351]
#                                                                  AUnstackLayer[0][352]
#                                                                  AUnstackLayer[0][353]
#                                                                  AUnstackLayer[0][354]
#                                                                  AUnstackLayer[0][355]
#                                                                  AUnstackLayer[0][356]
#                                                                  AUnstackLayer[0][357]
#                                                                  AUnstackLayer[0][358]
#                                                                  AUnstackLayer[0][359]
#                                                                  AUnstackLayer[0][360]
#                                                                  AUnstackLayer[0][361]
#                                                                  AUnstackLayer[0][362]
#                                                                  AUnstackLayer[0][363]
#                                                                  AUnstackLayer[0][364]
#                                                                  AUnstackLayer[0][365]
#                                                                  AUnstackLayer[0][366]
#                                                                  AUnstackLayer[0][367]
#                                                                  AUnstackLayer[0][368]
#                                                                  AUnstackLayer[0][369]
#                                                                  AUnstackLayer[0][370]
#                                                                  AUnstackLayer[0][371]
#                                                                  AUnstackLayer[0][372]
#                                                                  AUnstackLayer[0][373]
#                                                                  AUnstackLayer[0][374]
#                                                                  AUnstackLayer[0][375]
#                                                                  AUnstackLayer[0][376]
#                                                                  AUnstackLayer[0][377]
#                                                                  AUnstackLayer[0][378]
#                                                                  AUnstackLayer[0][379]
#                                                                  AUnstackLayer[0][380]
#                                                                  AUnstackLayer[0][381]
#                                                                  AUnstackLayer[0][382]
#                                                                  AUnstackLayer[0][383]
#                                                                  AUnstackLayer[0][384]
#                                                                  AUnstackLayer[0][385]
#                                                                  AUnstackLayer[0][386]
#                                                                  AUnstackLayer[0][387]
#                                                                  AUnstackLayer[0][388]
#                                                                  AUnstackLayer[0][389]
#                                                                  AUnstackLayer[0][390]
#                                                                  AUnstackLayer[0][391]
#                                                                  AUnstackLayer[0][392]
#                                                                  AUnstackLayer[0][393]
#                                                                  AUnstackLayer[0][394]
#                                                                  AUnstackLayer[0][395]
#                                                                  AUnstackLayer[0][396]
#                                                                  AUnstackLayer[0][397]
#                                                                  AUnstackLayer[0][398]
#                                                                  AUnstackLayer[0][399]
#                                                                  AUnstackLayer[0][400]
#                                                                  AUnstackLayer[0][401]
#                                                                  AUnstackLayer[0][402]
#                                                                  AUnstackLayer[0][403]
#                                                                  AUnstackLayer[0][404]
#                                                                  AUnstackLayer[0][405]
#                                                                  AUnstackLayer[0][406]
#                                                                  AUnstackLayer[0][407]
#                                                                  AUnstackLayer[0][408]
#                                                                  AUnstackLayer[0][409]
#                                                                  AUnstackLayer[0][410]
#                                                                  AUnstackLayer[0][411]
#                                                                  AUnstackLayer[0][412]
#                                                                  AUnstackLayer[0][413]
#                                                                  AUnstackLayer[0][414]
#                                                                  AUnstackLayer[0][415]
#                                                                  AUnstackLayer[0][416]
#                                                                  AUnstackLayer[0][417]
#                                                                  AUnstackLayer[0][418]
#                                                                  AUnstackLayer[0][419]
#                                                                  AUnstackLayer[0][420]
#                                                                  AUnstackLayer[0][421]
#                                                                  AUnstackLayer[0][422]
#                                                                  AUnstackLayer[0][423]
#                                                                  AUnstackLayer[0][424]
#                                                                  AUnstackLayer[0][425]
#                                                                  AUnstackLayer[0][426]
#                                                                  AUnstackLayer[0][427]
#                                                                  AUnstackLayer[0][428]
#                                                                  AUnstackLayer[0][429]
#                                                                  AUnstackLayer[0][430]
#                                                                  AUnstackLayer[0][431]
#                                                                  AUnstackLayer[0][432]
#                                                                  AUnstackLayer[0][433]
#                                                                  AUnstackLayer[0][434]
#                                                                  AUnstackLayer[0][435]
#                                                                  AUnstackLayer[0][436]
#                                                                  AUnstackLayer[0][437]
#                                                                  AUnstackLayer[0][438]
#                                                                  AUnstackLayer[0][439]
#                                                                  AUnstackLayer[0][440]
#                                                                  AUnstackLayer[0][441]
#                                                                  AUnstackLayer[0][442]
#                                                                  AUnstackLayer[0][443]
#                                                                  AUnstackLayer[0][444]
#                                                                  AUnstackLayer[0][445]
#                                                                  AUnstackLayer[0][446]
#                                                                  AUnstackLayer[0][447]
#                                                                  AUnstackLayer[0][448]
#                                                                  AUnstackLayer[0][449]
#                                                                  AUnstackLayer[0][450]
#                                                                  AUnstackLayer[0][451]
#                                                                  AUnstackLayer[0][452]
#                                                                  AUnstackLayer[0][453]
#                                                                  AUnstackLayer[0][454]
#                                                                  AUnstackLayer[0][455]
#                                                                  AUnstackLayer[0][456]
#                                                                  AUnstackLayer[0][457]
#                                                                  AUnstackLayer[0][458]
#                                                                  AUnstackLayer[0][459]
#                                                                  AUnstackLayer[0][460]
#                                                                  AUnstackLayer[0][461]
#                                                                  AUnstackLayer[0][462]
#                                                                  AUnstackLayer[0][463]
#                                                                  AUnstackLayer[0][464]
#                                                                  AUnstackLayer[0][465]
#                                                                  AUnstackLayer[0][466]
#                                                                  AUnstackLayer[0][467]
#                                                                  AUnstackLayer[0][468]
#                                                                  AUnstackLayer[0][469]
#                                                                  AUnstackLayer[0][470]
#                                                                  AUnstackLayer[0][471]
#                                                                  AUnstackLayer[0][472]
#                                                                  AUnstackLayer[0][473]
#                                                                  AUnstackLayer[0][474]
#                                                                  AUnstackLayer[0][475]
#                                                                  AUnstackLayer[0][476]
#                                                                  AUnstackLayer[0][477]
#                                                                  AUnstackLayer[0][478]
#                                                                  AUnstackLayer[0][479]
#                                                                  AUnstackLayer[0][480]
#                                                                  AUnstackLayer[0][481]
#                                                                  AUnstackLayer[0][482]
#                                                                  AUnstackLayer[0][483]
#                                                                  AUnstackLayer[0][484]
#                                                                  AUnstackLayer[0][485]
#                                                                  AUnstackLayer[0][486]
#                                                                  AUnstackLayer[0][487]
#                                                                  AUnstackLayer[0][488]
#                                                                  AUnstackLayer[0][489]
#                                                                  AUnstackLayer[0][490]
#                                                                  AUnstackLayer[0][491]
#                                                                  AUnstackLayer[0][492]
#                                                                  AUnstackLayer[0][493]
#                                                                  AUnstackLayer[0][494]
#                                                                  AUnstackLayer[0][495]
#                                                                  AUnstackLayer[0][496]
#                                                                  AUnstackLayer[0][497]
#                                                                  AUnstackLayer[0][498]
#                                                                  AUnstackLayer[0][499]
# __________________________________________________________________________________________________
# sentence_masks (InputLayer)     (None, 60, 50)       0
# __________________________________________________________________________________________________
# ASentence_GRU2 (GRU)            (None, 60, 50)       15150       ASentence_GRU1[0][0]
# __________________________________________________________________________________________________
# ATriplets_GRU1 (GRU)            (None, 30000, 50)    15150       concatenate_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 60, 50)       0           sentence_masks[0][0]
#                                                                  ASentence_GRU2[0][0]
# __________________________________________________________________________________________________
# ATriplets_GRU2 (GRU)            (None, 30000, 50)    15150       ATriplets_GRU1[0][0]
# __________________________________________________________________________________________________
# AMeanLayer (Lambda)             (None, 50)           0           multiply_2[0][0]
#                                                                  ATriplets_GRU2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 100)          0           AMeanLayer[0][0]
#                                                                  AMeanLayer[1][0]
# __________________________________________________________________________________________________
# Dense20 (Dense)                 (None, 20)           2020        concatenate_4[0][0]
# __________________________________________________________________________________________________
# Dense1 (Dense)                  (None, 1)            21          Dense20[0][0]
# ==================================================================================================
# Total params: 20,062,691
# Trainable params: 62,641
# Non-trainable params: 20,000,050
# __________________________________________________________________________________________________

# %%
triplet_indices[0].shape
# Out:
# (500, 60)
