# %%
import pandas as pd
import numpy as np
import sklearn as sns
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from sklearn import ensemble, metrics, model_selection, preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing
from sklearn.model_selection import StratifiedShuffleSplit

# Import function
from sklearn.model_selection import train_test_split

# select features
df = pd.read_json('/Users/surthi/Downloads/Archive (1)/mixed_features_gold_tagged_cleared_betterN/part-00000-e97dbd07-b5c8-4160-9c31-6430e44a03ac.json',lines=True)

df.head()
# Out:
#      articleId  articleLength  articleLengthN  companyId  \
# 0  33441345460           4105        0.331362   18353195
# 1  33441345460           4105        0.331362   10261568
# 2  33441345460           4105        0.331362   51217888
# 3  33441345460           4105        0.331362   18351925
# 4  33441345460           4105        0.331362   18348347
#
#    countOfDistinctIndustry  countOfDistinctIndustryN  countOfOccurence  \
# 0                        0                 -0.704151                 0
# 1                        2                 -0.564416                 3
# 2                        0                 -0.704151                 0
# 3                        0                 -0.704151                 0
# 4                        0                 -0.704151                 3
#
#    countOfOccurenceN  countOfOccurenceOfAliases  countOfOccurenceOfAliasesN  \
# 0          -0.692498                          0                   -0.677174
# ...

# %%
from sklearn import svm
from sklearn.metrics import confusion_matrix
from sklearn import tree, metrics, model_selection, preprocessing

svr = svm.SVC(max_iter=10000,random_state=0)

# #############################################################################
# Train classifiers
#
# For an initial search, a logarithmic grid with basis
# 10 is often helpful. Using a basis of 2, a finer
# tuning can be achieved but at a much higher cost.

C_range = np.logspace(-2, 10, 13)
gamma_range = np.logspace(-9, 3, 13)
param_grid = dict( C=C_range, gamma=gamma_range)
cv = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
grid = GridSearchCV(svr, param_grid=param_grid, cv=cv)

print(param_grid)
print(grid)
# Out:
# {'C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04, 1.e+05,
#        1.e+06, 1.e+07, 1.e+08, 1.e+09, 1.e+10]), 'gamma': array([1.e-09, 1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02,
#        1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03])}
# GridSearchCV(cv=StratifiedShuffleSplit(n_splits=5, random_state=0, test_size=0.2,
#             train_size=None),
#        error_score='raise-deprecating',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=10000, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04, 1.e+05,
#        1.e+06, 1.e+07, 1.e+08, 1.e+09, 1.e+10]), 'gamma': array([1.e-09, 1.e-08, 1.e-07, 1.e-06, 1.e-05, 1.e-04, 1.e-03, 1.e-02,
# ...

# %%
from sklearn.preprocessing import StandardScaler


# df['species_label'], _ = pd.factorize(df['iris'])
y = df['isGold']
X = df[['w2vScoreN','personScore','sumOfIndustryN',
        'countOfOccurenceOfAliasesN','countOfSignificantStringsN',
        'countryMatchByOverlapScore','directCityMatchScore','directCountryMatchScore',
        'directStateMatchScore','exactMatch','isIndustry','isProminentByItself','articleLengthN',
        'isProminentByParent','isSingleCompany','isTickerMatch','isUrlMatched','stateMatchByOverlapScore'
       ]]


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# split data randomly into 70% training and 30% test
X_train, X_test, y_train, y_test = model_selection.train_test_split(X_scaled, y, test_size=0.3, random_state=0)


grid.fit(X_train, y_train)
predicted_scaled = grid.predict(X_test)
cnf_matrix_scale = confusion_matrix(y_test, predicted_scaled)
print(cnf_matrix_scale)
# Out:
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# ...

# %%
print('HI')

grid.estimator.get_params()
# Out:
# HI
# {'C': 1.0,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'auto_deprecated',
#  'kernel': 'rbf',
#  'max_iter': 1000,
#  'probability': False,
#  'random_state': 0,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
count_misclassified = (y_test != predicted_scaled).sum()
print('Misclassified samples: {}'.format(count_misclassified))

accuracy = metrics.accuracy_score(y_test, predicted_scaled)
print('Accuracy: {:.2f}'.format(accuracy))

SVM_test=df.copy()
SVM_test['y_test']=y_test
SVM_test['y_pred']=pd.DataFrame(predicted_scaled)

from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
confusion_matrix(y_test, predicted_scaled)

print (recall_score(y_test, predicted_scaled))
print(precision_score(y_test, predicted_scaled))

SVM_test.to_json('/Users/surthi/Downloads/svm_scale_predict.json',orient='records', lines=True)
# Out:
# Misclassified samples: 180
# Accuracy: 0.90
# 0.801452784503632
# 0.7715617715617715

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_minmax = min_max_scaler.fit_transform(X)


# split data randomly into 70% training and 30% test
X_train, X_test, y_train, y_test = model_selection.train_test_split(X_minmax, y, test_size=0.3, random_state=0)


grid.fit(X_train, y_train)
predicted_scaled = grid.predict(X_test)
cnf_matrix_scale = confusion_matrix(y_test, predicted_scaled)
print(cnf_matrix_scale)
# Out:
# /Users/kavetiraviteja/venv/cbp/lib/python3.6/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# /Users/kavetiraviteja/venv/cbp/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /Users/kavetiraviteja/venv/cbp/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /Users/kavetiraviteja/venv/cbp/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# ...

# %%
count_misclassified = (y_test != predicted_scaled).sum()
print('Misclassified samples: {}'.format(count_misclassified))

accuracy = metrics.accuracy_score(y_test, predicted_scaled)
print('Accuracy: {:.2f}'.format(accuracy))

SVM_test=df.copy()
SVM_test['y_test']=y_test
SVM_test['y_pred']=pd.DataFrame(predicted_scaled)

SVM_test.to_json('/Users/kavetiraviteja/Downloads/svm_scaleminMax_predict.json',orient='records', lines=True)
# Out:
# Misclassified samples: 200
# Accuracy: 0.89
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-9d5cf38d5a68> in <module>
#       9 SVM_test['y_pred']=pd.DataFrame(predicted_scaled)
#      10
# ---> 11 SVM_test.to_json('/Users/kavetiraviteja/Downloads/svm_scaleminMax_predict.json',orient='records', lines=True)
#
# ~/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/pandas/core/generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
#    2272                             default_handler=default_handler,
#    2273                             lines=lines, compression=compression,
# -> 2274                             index=index)
#    2275
#    2276     def to_hdf(self, path_or_buf, key, **kwargs):
#
# ...

# %%
max_abs_scaler = preprocessing.MaxAbsScaler()
X_maxabs = max_abs_scaler.fit_transform(X)

# split data randomly into 70% training and 30% test
X_train, X_test, y_train, y_test = model_selection.train_test_split(X_minmax, y, test_size=0.3, random_state=0)


grid.fit(X_train, y_train)
predicted_scaled = grid.predict(X_test)
cnf_matrix_scale = confusion_matrix(y_test, predicted_scaled)
print(cnf_matrix_scale)
# Out:
# /Users/kavetiraviteja/venv/cbp/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /Users/kavetiraviteja/venv/cbp/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /Users/kavetiraviteja/venv/cbp/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /Users/kavetiraviteja/venv/cbp/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# ...

# %%
count_misclassified = (y_test != predicted_scaled).sum()
print('Misclassified samples: {}'.format(count_misclassified))

accuracy = metrics.accuracy_score(y_test, predicted_scaled)
print('Accuracy: {:.2f}'.format(accuracy))


SVM_test=df.copy()
SVM_test['y_test']=y_test
SVM_test['y_pred']=pd.DataFrame(predicted_scaled)

SVM_test.to_json('/Users/surthi/Downloads/svm_scalemaxabs_predict.json',orient='records', lines=True)
# Out:
# Misclassified samples: 178
# Accuracy: 0.90

# %%
X_scaled_1 = preprocessing.scale(X)
# split data randomly into 70% training and 30% test
X_train, X_test, y_train, y_test = model_selection.train_test_split(X_scaled_1, y, test_size=0.3, random_state=0)

grid.fit(X_train, y_train)
predicted_scaled = grid.predict(X_test)
cnf_matrix_scale = confusion_matrix(y_test, predicted_scaled)
print(cnf_matrix_scale)

count_misclassified = (y_test != predicted_scaled).sum()
print('Misclassified samples: {}'.format(count_misclassified))

accuracy = metrics.accuracy_score(y_test, predicted_scaled)
print('Accuracy: {:.2f}'.format(accuracy))
# Out:
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by the scale function.
#   """Entry point for launching an IPython kernel.
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# ...

# %%
quantile_transformer = preprocessing.QuantileTransformer(random_state=0)
X_train_trans = quantile_transformer.fit_transform(X)

# split data randomly into 70% training and 30% test
X_train, X_test, y_train, y_test = model_selection.train_test_split(X_train_trans, y, test_size=0.3, random_state=0)


grid.fit(X_train, y_train)
predicted_scaled = grid.predict(X_test)
cnf_matrix_scale = confusion_matrix(y_test, predicted_scaled)
print(cnf_matrix_scale)

count_misclassified = (y_test != predicted_scaled).sum()
print('Misclassified samples: {}'.format(count_misclassified))

accuracy = metrics.accuracy_score(y_test, predicted_scaled)
print('Accuracy: {:.2f}'.format(accuracy))


SVM_test=df.copy()
SVM_test['y_test']=y_test
SVM_test['y_pred']=pd.DataFrame(predicted_scaled)

SVM_test.to_json('/Users/kavetiraviteja/Downloads/svm_scalequantile_tran_predict.json',orient='records', lines=True)
# Out:
# /Users/kavetiraviteja/venv/cbp/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /Users/kavetiraviteja/venv/cbp/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /Users/kavetiraviteja/venv/cbp/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# /Users/kavetiraviteja/venv/cbp/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
# ...
