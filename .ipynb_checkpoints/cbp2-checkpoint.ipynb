# %%
import json
from pandas.io.json import json_normalize
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# data10 = open("/Users/surthi/Documents/cs230project/data/triplets/nonsingles10RecordsPerMentionAid/part-00000-6d8d4860-b569-41a7-94c6-4016af8cf4d3.json").read()
data = open("/Users/surthi/Downloads/cbp-apr-17-2019/final_validation_articles_features_with_gold_file.json").read()
json_data = [json.loads(str(item)) for item in data.strip().split('\n')]
df0 = json_normalize(json_data).drop(columns=["isCommon", "isTickerMatch", "popularity", "isFortune"])
df = df0[df0["isSingleCompanyMatch"] == 0.0].drop(columns=['isSingleCompanyMatch'])

# %%
bool_cols = ['exactMatch', 'fieldMatch', 'isIndustry', "tickerMatch", 'isPublic', 'isProminentByItself', 'isProminentByParent', 'isUrlMatched','isGold'] # 'isSingleCompanyMatch'
na_cols = ['articleLength', 'countOfDistinctIndustry',
          'countOfOccurence', 'countOfOccurenceOfAliases',
          'countOfOccurenceOfNamePreserveList', 'countOfSignificantStrings',
          'countOfUrlMatch', 'countryMatchByOverlapScore', 'directCityMatchScore',
          'directCountryMatchScore', 'directStateMatchScore', 'exactMatch',
          'fieldMatch', 'isIndustry', "tickerMatch",
          'isProminentByItself', 'isProminentByParent', 'isSingleCompanyMatch',
           'isUrlMatched', 'stateMatchByOverlapScore', 'sumOfIndustry', 'w2vScore'] # 'personScore', 

for k, v in df.iteritems():
    if k in bool_cols:
        v *= 1.0
    if k in non_bool_cols:
        v[v == -1000.0] = np.nan

print("Done")
# Out:
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# Done

# %%
df['tickerMatch'].describe()
# Out:
# count    10506.000000
# mean         0.018180
# std          0.133609
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: tickerMatch, dtype: float64

# %%
df.columns
# Out:
# Index(['articleId', 'articleLength', 'companyId', 'countOfDistinctIndustry',
#        'countOfOccurence', 'countOfOccurenceOfAliases',
#        'countOfOccurenceOfNamePreserveList', 'countOfSignificantStrings',
#        'countOfUrlMatch', 'countryMatchByOverlapScore', 'directCityMatchScore',
#        'directCountryMatchScore', 'directStateMatchScore', 'empCount',
#        'exactMatch', 'fieldMatch', 'isGold', 'isIndustry',
#        'isProminentByItself', 'isProminentByParent', 'isPublic',
#        'isUrlMatched', 'mentionMatched', 'personScore',
#        'stateMatchByOverlapScore', 'sumOfIndustry', 'tickerMatch', 'w2vScore'],
#       dtype='object')

# %%
print(df[df['isGold']==1.0].loc[:, 'isGold'].count(), df[df['isGold']==0.0].loc[:, 'isGold'].count())
# Out:
# 1219 9287

# %%
# df.loc[:, ['isIndustry', 'fieldMatch', 'isProminentByItself', 'isProminentByParent', 'isUrlMatched', 'isGold','exactMatch']].describe()
df.loc[:, ['articleLength', 'countOfDistinctIndustry',
          'countOfOccurence', 'countOfOccurenceOfAliases',
          'countOfOccurenceOfNamePreserveList', 'countOfSignificantStrings',
          'countOfUrlMatch', 'countryMatchByOverlapScore', 'directCityMatchScore',
          'directCountryMatchScore', 'directStateMatchScore', 'exactMatch',
          'fieldMatch', 'isIndustry', "tickerMatch", 
          'isProminentByItself', 'isProminentByParent', 'isSingleCompanyMatch',
           'isUrlMatched', 'personScore', 
          'stateMatchByOverlapScore', 'sumOfIndustry', 'w2vScore']].describe()
# Out:
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/pandas/core/indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#        articleLength  countOfDistinctIndustry  countOfOccurence  \
# count   10506.000000             10506.000000      10506.000000
# mean     3868.871692                 5.549305          3.054635
# std      5081.785687                 8.667736          3.933462
# min        39.000000                 0.000000          0.000000
# 25%      1939.000000                 0.000000          1.000000
# 50%      2920.000000                 2.000000          2.000000
# 75%      4451.000000                 7.000000          3.000000
# max     53140.000000                93.000000         69.000000
#
#        countOfOccurenceOfAliases  countOfOccurenceOfNamePreserveList  \
# count               10506.000000                        10506.000000
# mean                    0.182086                            0.183133
# std                     0.956586                            0.945927
# min                     0.000000                            0.000000
# 25%                     0.000000                            0.000000
# 50%                     0.000000                            0.000000
# 75%                     0.000000                            0.000000
# max                    17.000000                           17.000000
#
#        countOfSignificantStrings  countOfUrlMatch  countryMatchByOverlapScore  \
# count               10506.000000     10506.000000                10330.000000
# mean                    0.974681         0.020560                    0.265973
# std                     9.892893         0.224522                    0.249501
# min                     0.000000         0.000000                    0.000000
# 25%                     0.000000         0.000000                    0.000000
# 50%                     0.000000         0.000000                    0.500000
# 75%                     0.000000         0.000000                    0.500000
# max                   595.000000         7.000000                    0.500000
#
#        directCityMatchScore  directCountryMatchScore  ...    isIndustry  \
# count           8444.000000             10330.000000  ...  10506.000000
# mean               0.020725                 0.064530  ...      0.093375
# std                0.142470                 0.185896  ...      0.290971
# min                0.000000                 0.000000  ...      0.000000
# 25%                0.000000                 0.000000  ...      0.000000
# 50%                0.000000                 0.000000  ...      0.000000
# 75%                0.000000                 0.000000  ...      0.000000
# max                1.000000                 0.600000  ...      1.000000
#
#         tickerMatch  isProminentByItself  isProminentByParent  \
# count  10506.000000         10506.000000         10506.000000
# mean       0.018180             0.127451             0.058919
# std        0.133609             0.333493             0.235484
# min        0.000000             0.000000             0.000000
# 25%        0.000000             0.000000             0.000000
# 50%        0.000000             0.000000             0.000000
# 75%        0.000000             0.000000             0.000000
# max        1.000000             1.000000             1.000000
#
#        isSingleCompanyMatch  isUrlMatched   personScore  \
# count                   0.0  10506.000000  10506.000000
# mean                    NaN      0.012850   -752.712736
# std                     NaN      0.112632    431.455666
# min                     NaN      0.000000  -1000.000000
# 25%                     NaN      0.000000  -1000.000000
# 50%                     NaN      0.000000  -1000.000000
# 75%                     NaN      0.000000  -1000.000000
# max                     NaN      1.000000      0.000000
#
#        stateMatchByOverlapScore  sumOfIndustry      w2vScore
# count               7816.000000   10506.000000  10251.000000
# mean                   0.206525      45.454121      3.998785
# std                    0.319262     165.050969      9.624181
# min                    0.000000       0.000000     -0.079266
# 25%                    0.000000       0.000000      0.000000
# 50%                    0.000000       4.000000      0.000000
# 75%                    0.700000      17.000000      1.442548
# max                    0.700000    3997.000000     81.765974
#
# [8 rows x 23 columns]

# %%
golds = df[df['isGold'] == 1.0]
g_train, g_test = train_test_split(golds, test_size=0.2)

# %%
trainArticleIds = g_train['articleId'].to_list()
trainMentions = g_train['mentionMatched'].to_list()
testArticleIds = g_test['articleId'].to_list()
testMentions = g_test['mentionMatched'].to_list()
remainingArticleIds = trainArticleIds + testArticleIds
remainingMentions = trainMentions + testMentions

# %%
trainMask = (df['articleId'].isin(trainArticleIds) & df['mentionMatched'].isin(trainMentions))
train_df = df.loc[trainMask]
testMask = (df['articleId'].isin(testArticleIds) & df['mentionMatched'].isin(testMentions))
test_df = df.loc[testMask]
remainingMask = (~df['articleId'].isin(remainingArticleIds) & ~df['mentionMatched'].isin(remainingMentions))
remaining_df = df.loc[~trainMask & ~testMask]
remaining_train_df, remaining_test_df = train_test_split(remaining_df, test_size=0.2)
train = pd.concat([train_df, remaining_train_df])
test = pd.concat([test_df, remaining_test_df])

# %%
print(len(train), len(test))
print(len(train[train['isGold']==1.0]), len(test[test['isGold']==1.0]))
# Out:
# 8661 2102
# 1010 262

# %%
#train, test = train_test_split(df, test_size=0.2)

# %%
y_train = train.loc[:, train.columns == 'isGold']
x_train = train[train.columns.difference(['personScore', 'isGold', 'articleId', 'mentionMatched', 'companyId'])]
ids_train = train[['isGold', 'articleId', 'mentionMatched', 'companyId']]
y_test = test.loc[:, test.columns == 'isGold']
x_test = test[test.columns.difference(['personScore', 'isGold', 'articleId', 'mentionMatched', 'companyId'])]
ids_test = test[['isGold', 'articleId', 'mentionMatched', 'companyId']]

# %%
print(len(train),": Gold-", len(train[train["isGold"]==1]), ": NonGold-", len(train[train["isGold"]==0]))
print(len(test),": Gold-", len(test[test["isGold"]==1]), ": NonGold-", len(test[test["isGold"]==0]))
# Out:
# 8661 : Gold- 1010 : NonGold- 7651
# 2102 : Gold- 262 : NonGold- 1840

# %%
train_mean = x_train.mean()
train_std = x_train.std()
x_train.describe()
# Out:
#        articleLength  countOfDistinctIndustry  countOfOccurence  \
# count    8661.000000              8661.000000       8661.000000
# mean     3771.008660                 5.497633          3.075973
# std      4738.887305                 8.459407          4.012768
# min        39.000000                 0.000000          0.000000
# 25%      1929.000000                 0.000000          1.000000
# 50%      2875.000000                 2.000000          2.000000
# 75%      4378.000000                 7.000000          3.000000
# max     53140.000000                93.000000         69.000000
#
#        countOfOccurenceOfAliases  countOfOccurenceOfNamePreserveList  \
# count                8661.000000                         8661.000000
# mean                    0.176423                            0.178039
# std                     0.949804                            0.939354
# min                     0.000000                            0.000000
# 25%                     0.000000                            0.000000
# 50%                     0.000000                            0.000000
# 75%                     0.000000                            0.000000
# max                    17.000000                           17.000000
#
#        countOfSignificantStrings  countOfUrlMatch  countryMatchByOverlapScore  \
# count                8661.000000      8661.000000                 8513.000000
# mean                    0.931994         0.019859                    0.262363
# std                     8.648225         0.222982                    0.249709
# min                     0.000000         0.000000                    0.000000
# 25%                     0.000000         0.000000                    0.000000
# 50%                     0.000000         0.000000                    0.500000
# 75%                     0.000000         0.000000                    0.500000
# max                   595.000000         7.000000                    0.500000
#
#        directCityMatchScore  directCountryMatchScore  ...   fieldMatch  \
# count           6911.000000              8513.000000  ...  8661.000000
# mean               0.019968                 0.065335  ...     2.335527
# std                0.139901                 0.186913  ...     0.472202
# min                0.000000                 0.000000  ...     2.000000
# 25%                0.000000                 0.000000  ...     2.000000
# 50%                0.000000                 0.000000  ...     2.000000
# 75%                0.000000                 0.000000  ...     3.000000
# max                1.000000                 0.600000  ...     3.000000
#
#         isIndustry  isProminentByItself  isProminentByParent     isPublic  \
# count  8661.000000          8661.000000          8661.000000  8661.000000
# mean      0.095486             0.129662             0.059116     0.054497
# std       0.293901             0.335950             0.235855     0.227009
# min       0.000000             0.000000             0.000000     0.000000
# 25%       0.000000             0.000000             0.000000     0.000000
# 50%       0.000000             0.000000             0.000000     0.000000
# 75%       0.000000             0.000000             0.000000     0.000000
# max       1.000000             1.000000             1.000000     1.000000
#
#        isUrlMatched  stateMatchByOverlapScore  sumOfIndustry  tickerMatch  \
# count   8661.000000               6368.000000    8661.000000  8661.000000
# mean       0.012354                  0.204899      43.800600     0.018589
# std        0.110467                  0.318531     148.921299     0.135076
# min        0.000000                  0.000000       0.000000     0.000000
# 25%        0.000000                  0.000000       0.000000     0.000000
# 50%        0.000000                  0.000000       4.000000     0.000000
# 75%        0.000000                  0.700000      17.000000     0.000000
# max        1.000000                  0.700000    3997.000000     1.000000
#
#           w2vScore
# count  8449.000000
# mean      3.965205
# std       9.616087
# min      -0.079266
# 25%       0.000000
# 50%       0.000000
# 75%       1.480573
# max      81.765974
#
# [8 rows x 23 columns]

# %%
train_std
# Out:
# articleLength                          4738.887305
# countOfDistinctIndustry                   8.459407
# countOfOccurence                          4.012768
# countOfOccurenceOfAliases                 0.949804
# countOfOccurenceOfNamePreserveList        0.939354
# countOfSignificantStrings                 8.648225
# countOfUrlMatch                           0.222982
# countryMatchByOverlapScore                0.249709
# directCityMatchScore                      0.139901
# directCountryMatchScore                   0.186913
# directStateMatchScore                     0.119746
# empCount                              34383.006513
# exactMatch                                0.471879
# fieldMatch                                0.472202
# isIndustry                                0.293901
# isProminentByItself                       0.335950
# isProminentByParent                       0.235855
# isPublic                                  0.227009
# isUrlMatched                              0.110467
# stateMatchByOverlapScore                  0.318531
# sumOfIndustry                           148.921299
# tickerMatch                               0.135076
# w2vScore                                  9.616087
# dtype: float64

# %%
bool_cols.remove('isGold')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-680-d9214cb9a109> in <module>
# ----> 1 bool_cols.remove('isGold')
#
# ValueError: list.remove(x): x not in list

# %%
cols_to_normalize = [item for item in x_train.columns.tolist() if item not in bool_cols]
cols_to_normalize
# Out:
# ['articleLength',
#  'countOfDistinctIndustry',
#  'countOfOccurence',
#  'countOfOccurenceOfAliases',
#  'countOfOccurenceOfNamePreserveList',
#  'countOfSignificantStrings',
#  'countOfUrlMatch',
#  'countryMatchByOverlapScore',
#  'directCityMatchScore',
#  'directCountryMatchScore',
#  'directStateMatchScore',
#  'empCount',
#  'stateMatchByOverlapScore',
#  'sumOfIndustry',
#  'w2vScore']

# %%
x_train[bool_cols].isnull().values.any()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-609-2f1e44674f7a> in <module>
# ----> 1 x_train[bool_cols].isnull().values.any()
#
# ~/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['isSingleCompanyMatch'] not in index"

# %%
# delme.loc[:, 'articleLength'] = (delme.loc[:, 'articleLength'] - train_mean['articleLength'])/train_std['articleLength']

for col in cols_to_normalize:
    print(col)
    x_train.loc[:, col] = (x_train.loc[:, col] - train_mean[col])/train_std[col]
    x_test.loc[:, col] = (x_test.loc[:, col] - train_mean[col])/train_std[col]

print(len(x_test.columns))
x_train.describe()
# Out:
# articleLength
# countOfDistinctIndustry
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# countOfOccurence
# countOfOccurenceOfAliases
# countOfOccurenceOfNamePreserveList
# countOfSignificantStrings
# countOfUrlMatch
# countryMatchByOverlapScore
# directCityMatchScore
# directCountryMatchScore
# directStateMatchScore
# empCount
# stateMatchByOverlapScore
# sumOfIndustry
# w2vScore
# 23
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/pandas/core/indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
#        articleLength  countOfDistinctIndustry  countOfOccurence  \
# count   8.404000e+03             8.404000e+03      8.404000e+03
# mean   -2.938049e-17            -7.186594e-18     -1.743806e-17
# std     1.000000e+00             1.000000e+00      1.000000e+00
# min    -7.637340e-01            -6.416509e-01     -7.717137e-01
# 25%    -3.838763e-01            -6.416509e-01     -5.212316e-01
# 50%    -1.865658e-01            -4.133997e-01     -2.707495e-01
# 75%     1.184774e-01             1.572282e-01     -2.026747e-02
# max     9.830185e+00             9.972029e+00      1.651155e+01
#
#        countOfOccurenceOfAliases  countOfOccurenceOfNamePreserveList  \
# count               8.404000e+03                        8.404000e+03
# mean                1.395045e-17                       -1.690963e-17
# std                 1.000000e+00                        1.000000e+00
# min                -1.928740e-01                       -1.960606e-01
# 25%                -1.928740e-01                       -1.960606e-01
# 50%                -1.928740e-01                       -1.960606e-01
# 75%                -1.928740e-01                       -1.960606e-01
# max                 1.771195e+01                        1.773658e+01
#
#        countOfSignificantStrings  countOfUrlMatch  countryMatchByOverlapScore  \
# count               8.404000e+03     8.404000e+03                8.265000e+03
# mean                5.495630e-18    -1.479593e-18                8.382083e-17
# std                 1.000000e+00     1.000000e+00                1.000000e+00
# min                -9.464310e-02    -9.063376e-02               -1.061217e+00
# 25%                -9.464310e-02    -9.063376e-02               -1.061217e+00
# 50%                -9.464310e-02    -9.063376e-02                9.422000e-01
# 75%                -9.464310e-02    -9.063376e-02                9.422000e-01
# max                 5.588495e+01     3.108950e+01                9.422000e-01
#
#        directCityMatchScore  directCountryMatchScore  ...   fieldMatch  \
# count          6.737000e+03             8.265000e+03  ...  8404.000000
# mean          -7.567380e-17            -5.657476e-15  ...     2.345074
# std            1.000000e+00             1.000000e+00  ...     0.475421
# min           -1.424458e-01            -3.467099e-01  ...     2.000000
# 25%           -1.424458e-01            -3.467099e-01  ...     2.000000
# 50%           -1.424458e-01            -3.467099e-01  ...     2.000000
# 75%           -1.424458e-01            -3.467099e-01  ...     3.000000
# max            7.019174e+00             2.883907e+00  ...     3.000000
#
#         isIndustry  isProminentByItself  isProminentByParent     isPublic  \
# count  8404.000000          8404.000000          8404.000000  8404.000000
# mean      0.093884             0.127677             0.057949     0.053189
# std       0.291684             0.333750             0.233660     0.224423
# min       0.000000             0.000000             0.000000     0.000000
# 25%       0.000000             0.000000             0.000000     0.000000
# 50%       0.000000             0.000000             0.000000     0.000000
# 75%       0.000000             0.000000             0.000000     0.000000
# max       1.000000             1.000000             1.000000     1.000000
#
#        isUrlMatched  stateMatchByOverlapScore  sumOfIndustry  tickerMatch  \
# count   8404.000000              6.245000e+03   8.404000e+03  8404.000000
# mean       0.012256             -2.202853e-14   5.707001e-18     0.018087
# std        0.110033              1.000000e+00   1.000000e+00     0.133273
# min        0.000000             -6.417723e-01  -2.836347e-01     0.000000
# 25%        0.000000             -6.417723e-01  -2.836347e-01     0.000000
# 50%        0.000000             -6.417723e-01  -2.589068e-01     0.000000
# 75%        0.000000              1.557936e+00  -1.785413e-01     0.000000
# max        1.000000              1.557936e+00   2.442567e+01     1.000000
#
#            w2vScore
# count  8.209000e+03
# mean   7.162555e-17
# std    1.000000e+00
# min   -4.226130e-01
# 25%   -4.152101e-01
# 50%   -4.152101e-01
# 75%   -2.697479e-01
# max    8.075748e+00
#
# [8 rows x 23 columns]

# %%
x_test.describe()
# Out:
#        articleLength  countOfDistinctIndustry  countOfOccurence  \
# count    2102.000000              2102.000000       2102.000000
# mean        0.001723                -0.041650         -0.032899
# std         1.067639                 0.944338          0.923749
# min        -0.763734                -0.641651         -0.771714
# 25%        -0.388166                -0.641651         -0.521232
# 50%        -0.196142                -0.413400         -0.521232
# 75%         0.102517                 0.043103         -0.020267
# max         9.830185                 9.972029          7.744677
#
#        countOfOccurenceOfAliases  countOfOccurenceOfNamePreserveList  \
# count                2102.000000                         2102.000000
# mean                   -0.005478                           -0.014396
# std                     1.037175                            0.989220
# min                    -0.192874                           -0.196061
# 25%                    -0.192874                           -0.196061
# 50%                    -0.192874                           -0.196061
# 75%                    -0.192874                           -0.196061
# max                    15.605498                           15.626859
#
#        countOfSignificantStrings  countOfUrlMatch  countryMatchByOverlapScore  \
# count                2102.000000      2102.000000                 2065.000000
# mean                   -0.014704         0.004725                    0.022471
# std                     0.576056         1.000679                    0.998590
# min                    -0.094643        -0.090634                   -1.061217
# 25%                    -0.094643        -0.090634                   -1.061217
# 50%                    -0.094643        -0.090634                    0.942200
# 75%                    -0.094643        -0.090634                    0.942200
# max                    15.899526        31.089499                    0.942200
#
#        directCityMatchScore  directCountryMatchScore  ...   fieldMatch  \
# count           1707.000000              2065.000000  ...  2102.000000
# mean               0.029567                 0.003730  ...     2.341579
# std                1.096818                 1.004897  ...     0.474352
# min               -0.142446                -0.346710  ...     2.000000
# 25%               -0.142446                -0.346710  ...     2.000000
# 50%               -0.142446                -0.346710  ...     2.000000
# 75%               -0.142446                -0.346710  ...     3.000000
# max                7.019174                 2.883907  ...     3.000000
#
#         isIndustry  isProminentByItself  isProminentByParent     isPublic  \
# count  2102.000000          2102.000000          2102.000000  2102.000000
# mean      0.091342             0.126546             0.062797     0.054234
# std       0.288163             0.332543             0.242656     0.226533
# min       0.000000             0.000000             0.000000     0.000000
# 25%       0.000000             0.000000             0.000000     0.000000
# 50%       0.000000             0.000000             0.000000     0.000000
# 75%       0.000000             0.000000             0.000000     0.000000
# max       1.000000             1.000000             1.000000     1.000000
#
#        isUrlMatched  stateMatchByOverlapScore  sumOfIndustry  tickerMatch  \
# count   2102.000000               1571.000000    2102.000000  2102.000000
# mean       0.015224                  0.035923      -0.013190     0.018554
# std        0.122470                  1.015932       1.098087     0.134975
# min        0.000000                 -0.641772      -0.283635     0.000000
# 25%        0.000000                 -0.641772      -0.283635     0.000000
# 50%        0.000000                 -0.641772      -0.258907     0.000000
# 75%        0.000000                  1.557936      -0.178541     0.000000
# max        1.000000                  1.557936      22.299075     1.000000
#
#           w2vScore
# count  2042.000000
# mean      0.000212
# std       0.997327
# min      -0.423441
# 25%      -0.415210
# 50%      -0.415210
# 75%      -0.253577
# max       7.683993
#
# [8 rows x 23 columns]

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values = "NaN", strategy = "mean", axis = 0) 
imputer = imputer.fit(x_train) 
imputed_x_train = pd.DataFrame(imputer.fit_transform(x_train))
imputed_x_train.columns = x_train.columns
imputed_x_train.index = x_train.index

imputer1 = Imputer(missing_values = "NaN", strategy = "mean", axis = 0) 
imputer1 = imputer1.fit(x_test) 
imputed_x_test = pd.DataFrame(imputer.fit_transform(x_test))
imputed_x_test.columns = x_test.columns
imputed_x_test.index = x_test.index
# Out:
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
imputed_x_test.head()
# Out:
#       articleLength  countOfDistinctIndustry  countOfOccurence  \
# 1714       0.374442                -0.413400         -0.521232
# 4868       0.214040                -0.641651          0.981661
# 5876      -0.436945                -0.641651         -0.521232
# 4093      -0.328813                -0.527525          1.733107
# 1025       0.742729                -0.071023         -0.521232
#
#       countOfOccurenceOfAliases  countOfOccurenceOfNamePreserveList  \
# 1714                  -0.192874                           -0.196061
# 4868                   0.860351                            0.858801
# 5876                  -0.192874                           -0.196061
# 4093                   0.860351                            0.858801
# 1025                  -0.192874                           -0.196061
#
#       countOfSignificantStrings  countOfUrlMatch  countryMatchByOverlapScore  \
# 1714                  -0.094643        -0.090634                    0.942200
# 4868                  -0.000560        -0.090634                   -1.061217
# 5876                  -0.094643        -0.090634                   -1.061217
# 4093                  -0.000560         4.363671                    0.942200
# 1025                  -0.094643        -0.090634                    0.942200
#
#       directCityMatchScore  directCountryMatchScore  ...  fieldMatch  \
# 1714             -0.142446                -0.346710  ...         2.0
# 4868             -0.142446                -0.346710  ...         2.0
# 5876             -0.142446                -0.346710  ...         2.0
# 4093             -0.142446                 2.883907  ...         3.0
# 1025             -0.142446                 2.883907  ...         3.0
#
#       isIndustry  isProminentByItself  isProminentByParent  isPublic  \
# 1714         0.0                  0.0                  0.0       0.0
# 4868         0.0                  0.0                  0.0       0.0
# 5876         0.0                  0.0                  0.0       0.0
# 4093         0.0                  0.0                  0.0       0.0
# 1025         0.0                  0.0                  0.0       0.0
#
#       isUrlMatched  stateMatchByOverlapScore  sumOfIndustry  tickerMatch  \
# 1714           0.0                  1.557936      -0.215633          0.0
# 4868           0.0                 -0.641772      -0.283635          0.0
# 5876           0.0                  0.035923      -0.283635          0.0
# 4093           1.0                  1.557936      -0.277453          0.0
# 1025           0.0                  1.557936      -0.240361          0.0
#
#       w2vScore
# 1714  1.760441
# 4868 -0.415210
# 5876  1.921085
# 4093 -0.415210
# 1025 -0.415210
#
# [5 rows x 23 columns]

# %%
# https://stackabuse.com/implementing-svm-and-kernel-svm-with-pythons-scikit-learn/
from sklearn.svm import SVC, SVR 
svclassifier = SVR(kernel='rbf')  
svclassifier.fit(imputed_x_train, y_train)
# Out:
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/surthi/Documents/mygitrepo/cs230-code-examples/tensorflow/nlp/cs230/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(imputed_x_test)

# %%
type(ids_test)
y_pred_df = pd.DataFrame(y_pred)
y_pred_df.columns = ['y_pred']
y_pred_df.index = y_test.index

# %%
# concat_df = pd.concat([ids_test,y_pred_df]).sort_index().reset_index(drop=True)
concat_df = ids_test.join(y_pred_df)

# %%
concat_df['y_pred_max'] = concat_df.groupby(['articleId', 'mentionMatched'])['y_pred'].transform(max)

# %%
def f(row):
    if row['y_pred_max'] == row['y_pred']:
        val = row['y_pred_max']
    else:
        val = 0.0
    return val

concat_df['isGold_pred'] = concat_df.apply(f, axis=1)

# %%
concat_df.head()
# Out:
#       isGold    articleId    mentionMatched companyId    y_pred  y_pred_max  \
# 1714     0.0  37273022274         genentech  10337618  0.095483    0.097901
# 4868     0.0  37263059947           bluefin  51442938  0.036620    0.073631
# 5876     0.0  37263419698  internet service   2037254  0.074440    0.077132
# 4093     1.0  33501798480            unifor    362460  0.199594    0.199594
# 1025     0.0  37268200186       pacific rim   9485914  0.098903    0.099021
#
#       isGold_pred
# 1714     0.000000
# 4868     0.000000
# 5876     0.000000
# 4093     0.199594
# 1025     0.000000

# %%
concat_df.groupby(['articleId', 'mentionMatched']).size() #agg(['count'])
# df.groupby(['col1', 'col2']).size()
# Out:
# articleId    mentionMatched
# 33434320607  cbre capital markets              1
#              greystone                         2
# 33436232763  booker group                      1
#              tesco                             2
# 33436371207  nokia                             4
#              vodafone                          2
# 33437220574  bt group                          1
#              deutsche bank                     1
#              morgan stanley                    1
# 33437358686  athens regional medical center    1
#              piedmont healthcare               1
# 33437605232  credit suisse                     3
# 33437642422  connected services                1
# 33438243298  advent international              3
# 33438529545  nokia                             2
# 33439705569  wipro limited                     1
# 33439829858  nokia                             2
#              vodafone                          1
# 33440752371  spacex                            2
# 33441345460  baker botts                       2
#              shearman and sterling             3
# 33442077318  barnes and noble                  1
#              cim group                         1
#              odeon                             1
# 33443428339  consumer products                 3
# 33444441002  bank montreal                     1
# 33444856468  chanel                            2
# 33445034916  auto expo                         2
# 33450742209  mapletree investments             1
#              oakwood worldwide                 1
#                                               ..
# 37351738559  atms                              2
#              cash management systems           1
# 37351775717  portland state university         1
# 37351777219  stmicroelectronics                1
#              vat group                         2
# 37351994170  tanaka                            1
# 37352072666  national council la raza          1
# 37352338784  ivanti                            2
# 37352568696  family services                   3
# 37352631498  asia pacific                      1
#              raw materials                     1
# 37352726391  walgreens boots alliance          1
# 37352902337  tyson foods                       1
# 37352908392  european union                    2
#              reuters                           4
#              tradeweb                          2
# 37352963619  reuters                           2
# 37353031529  nasdaq                            1
#              thomson reuters                   1
# 37353111311  inspection services               2
# 37353113866  general electric                  1
# 37353114005  gasum                             1
# 37353362629  dow jones newswires               1
# 37353389825  quick facts                       2
# 37353664362  gartner                           3
#              lenovo                            3
# 37353818651  martindale hubbell                1
# 37354090672  health center                     3
# 37354353183  asia pacific                      1
# 37354416282  griffin industries inc            1
# Length: 1379, dtype: int64

# %%
concat_df.head()
# Out:
#       isGold    articleId    mentionMatched companyId    y_pred  y_pred_max  \
# 1714     0.0  37273022274         genentech  10337618  0.095483    0.097901
# 4868     0.0  37263059947           bluefin  51442938  0.036620    0.073631
# 5876     0.0  37263419698  internet service   2037254  0.074440    0.077132
# 4093     1.0  33501798480            unifor    362460  0.199594    0.199594
# 1025     0.0  37268200186       pacific rim   9485914  0.098903    0.099021
#
#       isGold_pred  mention_cnt
# 1714     0.000000          NaN
# 4868     0.000000          NaN
# 5876     0.000000          NaN
# 4093     0.199594          NaN
# 1025     0.000000          NaN

# %%
concat_df[concat_df['mentionMatched'] == 'unifor'].head()
# Out:
#       isGold    articleId mentionMatched companyId    y_pred  y_pred_max  \
# 4093     1.0  33501798480         unifor    362460  0.199594    0.199594
#
#       isGold_pred  mention_cnt
# 4093     0.199594          NaN

# %%
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(y_test, y_pred))  
print(classification_report(y_test, y_pred))
# Out:
# [[1827   42]
#  [ 100  134]]
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.98      0.96      1869
#          1.0       0.76      0.57      0.65       234
#
#    micro avg       0.93      0.93      0.93      2103
#    macro avg       0.85      0.78      0.81      2103
# weighted avg       0.93      0.93      0.93      2103
